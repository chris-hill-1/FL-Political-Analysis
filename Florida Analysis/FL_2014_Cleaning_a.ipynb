# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import csv
import os
import glob

# %% [markdown]
# ## Step 1: Reformat and Ingest Data

# %%
# Combine county files into single dataframe
def merge_files(directory):
    target_files = glob.glob(directory)
    combined_df = pd.DataFrame()
    for file in target_files:
        df = pd.read_table(file, names=['county_code', 'county_name', 'elec_num', 'elec_date', 'elec_name', 'precinct_id', 'poll_loc', 'total_reg', 'total_reg_r', 'total_reg_d', 'total_reg_other', 'contest_name', 'district', 'contest_code', 'cand_or_issue', 'cand_party', 'cand_id', 'doe_num', 'vote_total'], encoding_errors='replace')
        combined_df = pd.concat([combined_df, df])
    return combined_df

# %%
location = "C:\\Users\\canor\\Documents\\GitHub\\FL-Political-Analysis\\Florida Analysis\\FL 2014 by Precinct\\*"

df = merge_files(location)

# %%
# Examine dataframe for size, dtypes, and NaNs
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 385323 entries, 0 to 1119
# Data columns (total 19 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   county_code      385323 non-null  object
#  1   county_name      385323 non-null  object
#  2   elec_num         385323 non-null  int64
#  3   elec_date        385323 non-null  object
#  4   elec_name        385323 non-null  object
#  5   precinct_id      385323 non-null  object
#  6   poll_loc         340897 non-null  object
#  7   total_reg        385323 non-null  int64
#  8   total_reg_r      385323 non-null  int64
#  9   total_reg_d      385323 non-null  int64
#  10  total_reg_other  385323 non-null  int64
#  11  contest_name     385323 non-null  object
#  12  district         349577 non-null  object
#  13  contest_code     385323 non-null  int64
#  14  cand_or_issue    385323 non-null  object
#  15  cand_party       365969 non-null  object
#  16  cand_id          380165 non-null  float64
#  17  doe_num          385323 non-null  int64
#  18  vote_total       385323 non-null  int64
# dtypes: float64(1), int64(8), object(10)
# memory usage: 58.8+ MB

# %%
df.sample(10)
# Out:
#       county_code county_name  elec_num   elec_date              elec_name  \
# 32208         BRO     Broward     10218  11/04/2014  2014 General Election
# 5076          POL        Polk     10218  11/04/2014  2014 General Election
# 2812          BRE     Brevard     10218  11/04/2014  2014 General Election
# 6982          SEM    Seminole     10218  11/04/2014  2014 General Election
# 147           GAD     Gadsden     10218  11/04/2014  2014 General Election
# 242           CLM    Columbia     10218  11/04/2014  2014 General Election
# 2213          BRE     Brevard     10218  11/04/2014  2014 General Election
# 29356         BRO     Broward     10218  11/04/2014  2014 General Election
# 560           LEO        Leon     10218  11/04/2014  2014 General Election
# 4446          PAS       Pasco     10218  11/04/2014  2014 General Election
#
#       precinct_id                                           poll_loc  \
# 32208        V024                                           V024 454
# 5076          243  SHEPHERDS COMMUNITY UNITED METHODIST 2165 SHEP...
# 2812          133                                                NaN
# 6982           78                                        Precinct 78
# 147             3                           Pre. 3 Concord Fire Dept
# 242           112                          112 Supv Elections Office
# 2213          126                                                NaN
# 29356        T023                                           T023 412
# 560          1301             1301-1302  -- Lincoln Neighborhood Ctr
# 4446           75                           075 - MAGNOLIA VALLEY 74
#
#        total_reg  total_reg_r  total_reg_d  total_reg_other  \
# 32208       1950            0            0                0
# 5076        4671         2008         1492             1171
# 2812           0            0            0                0
# 6982      266005       105244        88123            72638
# 147         1031            0            0                0
# 242          552            0            0                0
# 2213           0            0            0                0
# 29356       1293            0            0                0
# 560          980            0            0                0
# 4446        3215            0            0                0
#
#                                        contest_name  \
# 32208                   Commissioner of Agriculture
# 5076                                    Amendment 3
# 2812               Governor and Lieutenant Governor
# 6982                                  Circuit Judge
# 147                                Attorney General
# 242                       Retention of Clay Roberts
# 2213                               Attorney General
# 29356  Broward Soil and Water Conservation District
# 560                         Chief Financial Officer
# 4446                            County Commissioner
#
#                              district  contest_code          cand_or_issue  \
# 32208                                        160800            Adam Putnam
# 5076                              NaN        900300             UnderVotes
# 2812                                         160000  Scott / Lopez-Cantera
# 6982                         Group 13        551813  Number of Under Votes
# 147                                          160200              Pam Bondi
# 242    First District Court of Appeal        520105                    Yes
# 2213                                         160200         Bill Wohlsifer
# 29356                         Group 4        830064              OverVotes
# 560                                          160500  William "Will" Rankin
# 4446                       District 2        380020             UnderVotes
#
#       cand_party      cand_id  doe_num  vote_total
# 32208        REP  113549963.0    60369         325
# 5076         NaN          0.0      902         169
# 2812         REP  103093132.0    61253           0
# 6982          NP          NaN      902           0
# 147          REP  110471335.0    60487         305
# 242          NOP  105003932.0       10         154
# 2213         LPF  111846393.0    61259           0
# 29356                     0.0      901           0
# 560          DEM  114807511.0    61112         336
# 4446                      0.0      902          70

# %% [markdown]
# ## Step 2: Removing Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No dupes! Great!

# %% [markdown]
# ## Step 3: Removing Extraneous Columns

# %%
df = df.drop(columns=['total_reg_r', 'total_reg_d', 'total_reg_other', 'elec_num', 'elec_name'])
df.sample(5)
# Out:
#       county_code county_name   elec_date precinct_id  \
# 30961         DAD  Miami-Dade  11/04/2014       626.0
# 1551          CHA   Charlotte  11/04/2014          23
# 3451          POL        Polk  11/04/2014         314
# 5769          SEM    Seminole  11/04/2014          66
# 13910         DAD  Miami-Dade  11/04/2014       304.0
#
#                                                 poll_loc  total_reg  \
# 30961                                   PCT 626/648 0396        564
# 1551                               ENG BEACH VILLAS 0029       1064
# 3451   1ST BAPTIST CHURCH OF LUCERNE PARK 5650 STATE ...       2969
# 5769                                         Precinct 66     266005
# 13910                                       PCT 304 0173       6749
#
#                                             contest_name  \
# 30961                   Governor and Lieutenant Governor
# 1551   Amendment No. 3: PROSPECTIVE APPOINTMENT OF CE...
# 3451                                     2nd DCA - Sleet
# 5769                         Commissioner of Agriculture
# 13910                   Governor and Lieutenant Governor
#
#                               district  contest_code          cand_or_issue  \
# 30961                                         160000  Scott / Lopez-Cantera
# 1551                                          900300       No for Rejection
# 3451   Second District Court of Appeal        520203                     No
# 5769                               NaN        160800               Write-in
# 13910                                         160000  Scott / Lopez-Cantera
#
#       cand_party      cand_id  doe_num  vote_total
# 30961        REP  103093132.0    61253         173
# 1551         NOP          0.0       20         309
# 3451         NOP  110555691.0       20         426
# 5769          NP          NaN      900           2
# 13910        REP  103093132.0    61253         637

# %% [markdown]
# ## Step 4: Narrowing to Races
#
# We're only interested in: Presidential, Gubernatorial, U.S. Congress, U.S. Senate, State House, and State Senate races.

# %%
# Look at all listed races and select those that are relevant
df['contest_name'].unique()
# Out:
# array(['U.S. Representative', 'Governor and Lieutenant Governor',
#        'Attorney General', 'Chief Financial Officer',
#        'Commissioner of Agriculture', 'Tax Collector',
#        'County Commissioner', 'Retention of Robert T. Benton',
#        'Retention of Joseph Lewis, Jr.', 'Retention of Scott Makar',
#        'Retention of Tim Osterhaus', 'Retention of Clay Roberts',
#        'Amendment No. 1: Water and Land Conservation - Dedicates funds to acquire and restore Florida conservation and recreation lands',
#        'Amendment No. 2: Use of Marijuana for Certain Medical Conditions',
#        'Amendment No. 3: PROSPECTIVE APPOINTMENT OF CERTAIN JUDICIAL VACANCIES',
#        'State Representative', 'Clerk of the Circuit Court',
#        'School Board', 'Canaveral Port Authority',
#        'Retention of Wendy W. Berger', 'Retention of Kerry I. Evander',
#        'Retention of Charles Alan Lawson',
#        'Retention of Richard B. Orfinger',
#        'Retention of William David Palmer',
#        'Retention of Thomas D. Sawaya', 'Retention of F. Rand Wallis',
#        'Circuit Judge', 'Barefoot Bay Recreation District (Vote for 3)',
#        'Viera East Community Development District',
#        'Baytree Community Development District', 'State Senator',
#        'Retention of Alan O. Forst', 'Retention of Mark W. Klingensmith',
#        'Retention of W. Matthew Stevenson',
#        'Retention of Martha C. Warner', 'County Court Judge',
#        'Broward Soil and Water Conservation District',
#        'Plantation Acres Improvement District (Vote for 3)',
#        'Monterra Community Development District',
#        'Walnut Creek Community Development District',
#        'Charlotte County Airport Authority',
#        'Retention of Chris W. Altenbernd',
#        'Retention of Morris Silberman', 'Retention of Daniel H. Sleet',
#        'Riverwood Community Development District',
#        'Englewood Area Fire Control District', 'Englewood Water District',
#        'Heritage Lake Park Community Development District',
#        'Heritage Oak Park Community Development District',
#        'Citrus County Mosquito Control District',
#        'Homosassa Special Water District',
#        'Clay Soil and Water Conservation District',
#        'Pine Ridge Plantation Community Development District',
#        'Middle Village Community Development District',
#        'South Village Community Development District',
#        'Fleming Island Plantation Community Development District',
#        'Collier Soil and Water Conservation District',
#        'East Naples Fire Control District',
#        'Golden Gate Fire Control and Rescue District',
#        'Verona Walk Community Development District',
#        "Fiddler's Creek Community Development District",
#        "Fiddler's Creek Community Development District #2",
#        'North Naples Fire Control and Rescue District',
#        'Mediterra South Community Development District',
#        'Heritage Greens Community Development District',
#        'Big Corkscrew Island Fire Control and Rescue District',
#        'Immokalee Fire Control District', 'Retention of Barbara Lagoa',
#        'Retention of Thomas Logue', 'Retention of Vance E. Salter',
#        'Property Appraiser',
#        'Midtown Miami Community Development District',
#        'Lakes by the Bay South Community Development District',
#        'Duval Soil and Water Conservation District',
#        'Santa Rosa Island Authority',
#        'Grand Haven Community Development District',
#        'Sterling Hill Community Development District',
#        'Hillsborough Soil and Water Conservation District',
#        'Tampa Palms Open Space & Transportation Community Development District',
#        'Arbor Green Community Development District',
#        'Cory Lakes Community Development District',
#        'Cheval West Community Development District',
#        'Fishhawk II Community Development District',
#        'Harbor Bay Community Development District',
#        'Mira Lago West Community Development District',
#        'Panther Trace II Community Development District',
#        'Lake Saint Charles Community Development District',
#        'Shall Judge Alan O. Forst be retained in Office?',
#        'Shall Judge Mark W. Klingensmith be retained in Office?',
#        'Shall Judge W. Matthew Stevenson be retained in Office?',
#        'Shall Judge Martha C. Warner be retained in Office?',
#        'Indian River County Hospital District',
#        'Water and Land Conservation - Dedicates funds to acquire and restore Florida conservation and recreation lands',
#        'Use of Marijuana for Certain Medical Conditions',
#        'PROSPECTIVE APPOINTMENT OF CERTAIN JUDICIAL VACANCIES',
#        'Indian River Mosquito Control District',
#        'Lake County Water Authority',
#        'Lee Memorial Health System Board of Directors',
#        'Lee County Mosquito Control District',
#        'Lehigh Acres Fire Control and Rescue District',
#        'Fort Myers Shores Fire Protection and Rescue Service District',
#        'South Trail Fire Protection and Rescue Service District',
#        'San Carlos Park Fire Protection and Rescue Service District',
#        'Bonita Springs Fire Control and Rescue District',
#        'Iona-McGregor Fire Protection and Rescue Service District',
#        'Fort Myers Beach Fire Control District',
#        'Parklands West Community Development District',
#        'Gateway Services District',
#        'Paseo Community Development District',
#        'Bayside Improvement Community Development District',
#        'Stoneybrook Community Development District',
#        'Habitat Community Development District',
#        'Laguna Lakes Community Development District',
#        'Leon Soil and Water Conservation District',
#        'Piney Z Community Development District',
#        'Capital Region Community Development District',
#        'Superintendent of Schools',
#        'Manatee County Mosquito Control District',
#        'North River Fire District',
#        'Palms of Terra Ceia Bay Community Development District',
#        'Parrish Fire Control District',
#        'Harrison Ranch Community Development District',
#        'Heritage Harbour South Community Development District',
#        'West Manatee Fire and Rescue District',
#        'Tara Community Development District',
#        'Lakewood Ranch Community Development District 5',
#        'Florida Keys Mosquito Control District',
#        'Key Largo Wastewater Treatment District (Vote for 3)',
#        'Key Largo Fire Rescue and Emergency Medical Services District',
#        'Ocean City-Wright Fire Control District',
#        'East Niceville Fire District', 'Destin Fire Control District',
#        'North Bay Fire District', 'Florosa Fire Control District',
#        'Orange Soil and Water Conservation District',
#        'Falcon Trace Community Development District',
#        'East Park Community Development District',
#        'Osceola Soil and Water Conservation District',
#        'Celebration Community Development District',
#        'Anthem Park Community Development District',
#        'U.S. REPRESENTATIVE', 'GOVERNOR AND  LT.GOVERNOR',
#        'ATTORNEY GENERAL', 'CHIEF FINANCIAL OFFICER',
#        'COMMISSIONER OF AGRICULTURE', 'STATE SENATOR',
#        'STATE REPRESENTATIVE', 'COUNTY COMMISSION',
#        'PORT OF PALM BEACH DISTRICT', 'JUDGE ALAN O. FORST',
#        'JUDGE MARK W. KLINGENSMITH', 'JUDGE W. MATTHEW STEVENSON',
#        'JUDGE MARTHA C. WARNER', 'SCHOOL BOARD',
#        'INDIAN TRAIL IMPROVEMENT DISTRICT',
#        'PALM BEACH SOIL AND WATER CONSERVATION DISTRICT', 'AMENDMENT 1',
#        'AMENDMENT 2', 'AMENDMENT 3',
#        'COUNTY QUESTION - CHILDREN SERVICES',
#        'COUNTY QUESTION - SCHOOL BOARD',
#        'PALM BEACH GARDENS - QUESTION 1',
#        'PALM BEACH GARDENS - QUESTION 2',
#        'Pasco County Mosquito Control District',
#        'Dupree Lakes Community Development District',
#        'Waters Edge Community Development District',
#        'Lake Bernadette Community Development District',
#        'Preserve at Wilderness Lake Community Development District',
#        'The Groves Community Development District',
#        'Lexington Oaks Community Development District',
#        'Meadow Pointe Community Development District',
#        'Meadow Pointe II Community Development District',
#        'Seven Oaks Community Development District',
#        'Lealman Special Fire Control District',
#        'Pinellas Suncoast Fire and Rescue District',
#        'Palm Harbor Special Fire Control and Rescue District',
#        'East Lake Tarpon Special Fire Control District',
#        '2nd DCA - Silberman', '2nd DCA - Sleet',
#        'Lake Ashton II - Seat 3', 'Congress 10', 'Amendment 1',
#        'Amendment 2', 'Governor', 'Congress 9', 'House 39', 'House 40',
#        'House 41', 'House 42', '2nd DCA - Altenbernd',
#        'Lake Ashton - Seat 3', 'Lake Ashton - Seat 4', 'Amendment 3',
#        'Congress 15', 'Congress 17', 'Senate 14',
#        'Sarasota County Charter Review Board',
#        'Sarasota Soil and Water Conservation District',
#        'Lakeside Plantation Community Development District',
#        'Venetian Community  Development District',
#        'Representative in Congress', 'FIFTH DCA BERGER',
#        'FIFTH DCA EVANDER', 'FIFTH DCA LAWSON', 'FIFTH DCA ORFINGER',
#        'FIFTH DCA PALMER', 'FIFTH DCA SAWAYA', 'FIFTH DCA WALLIS',
#        'City of Sanford', 'City of Longwood', 'City of Winter Springs',
#        'City of Oviedo',
#        'Saint Augustine-Saint Johns County Airport Authority',
#        'Anastasia Mosquito Control District',
#        'Julington Creek Plantation Community Development District',
#        'Durbin Crossing Community Development District',
#        'Aberdeen Community Development District',
#        'Sampson Creek Community Development District',
#        'Glen St. Johns Community Development District',
#        'Saint Augustine Port',
#        'Turnbull Creek Community Development District',
#        'Marshall Creek Community Development District',
#        'Saint Lucie West Service District',
#        'River Place on the St. Lucie Community Development District',
#        'Portofino Isles Community Development District',
#        'Village Community Development District No. 1',
#        'Village Community Development District No. 5',
#        'Village Community Development District No. 6',
#        'Village Community Development District No. 8',
#        'Village Community Development District No. 7', 'Sheriff',
#        'County Council', 'Volusia Soil and Water Conservation District',
#        'South Walton County Mosquito Control District',
#        'South Walton Fire District'], dtype=object)

# %% [markdown]
# Above, we can that 1) there are a lot of races represented in the data.

# %%
df['contest_name'] = df['contest_name'].replace(dict.fromkeys(['Congress 10', 'Congress 9', 'Congress 15', 'Congress 17', 'Representative in Congress', 'U.S. REPRESENTATIVE'], 'U.S. Representative'))\
.replace(dict.fromkeys(['GOVERNOR AND  LT.GOVERNOR', 'Governor'], 'Governor and Lieutenant Governor'))\
.replace(dict.fromkeys(['STATE REPRESENTATIVE', 'House 39', 'House 40', 'House 41', 'House 42'], 'State Representative'))\
.replace(dict.fromkeys(['STATE SENATOR', 'Senate 14'], 'State Senator'))

# %%
df = df[df.contest_name.isin(['U.S. Representative',\
                              'Governor and Lieutenant Governor',\
                              'State Representative',\
                              'U.S. Representative',\
                              'State Senator'])]\
                            .reset_index()

df.info()

# %% [markdown]
# ## Step 4: Dealing With NaN Cells

# %%
# Looking for any rows with nulls
df_nan = df[df.isna().any(axis=1)]
df_nan
# Out:
#        index county_code county_name   elec_date precinct_id    poll_loc  \
# 1987       0         BRE     Brevard  11/04/2014         100         NaN
# 1988       1         BRE     Brevard  11/04/2014         100         NaN
# 1989       2         BRE     Brevard  11/04/2014         100         NaN
# 1990       3         BRE     Brevard  11/04/2014         100         NaN
# 1991       4         BRE     Brevard  11/04/2014         100         NaN
# ...      ...         ...         ...         ...         ...         ...
# 77037   7398         SEM    Seminole  11/04/2014           9  Precinct 9
# 77038   7399         SEM    Seminole  11/04/2014           9  Precinct 9
# 77039   7400         SEM    Seminole  11/04/2014           9  Precinct 9
# 77041   7406         SEM    Seminole  11/04/2014           9  Precinct 9
# 77042   7407         SEM    Seminole  11/04/2014           9  Precinct 9
#
#        total_reg                      contest_name     district  contest_code  \
# 1987        1914               U.S. Representative   District 8        140080
# 1988        1914               U.S. Representative   District 8        140080
# 1989        1914               U.S. Representative   District 8        140080
# 1990        1914               U.S. Representative   District 8        140080
# 1991        1914               U.S. Representative   District 8        140080
# ...          ...                               ...          ...           ...
# 77037     266005  Governor and Lieutenant Governor          NaN        160000
# 77038     266005  Governor and Lieutenant Governor          NaN        160000
# 77039     266005  Governor and Lieutenant Governor          NaN        160000
# 77041     266005                     State Senator  District 10        240100
# 77042     266005                     State Senator  District 10        240100
#
#                cand_or_issue cand_party      cand_id  doe_num  vote_total
# 1987              Bill Posey        REP  100928199.0    60309         730
# 1988       Gabriel Rothblatt        DEM  119321677.0    60345         337
# 1989            WriteinVotes                     0.0      900           2
# 1990               OverVotes                     0.0      901           0
# 1991              UnderVotes                     0.0      902          58
# ...                      ...        ...          ...      ...         ...
# 77037             Rick Scott        REP  103093132.0    61253         848
# 77038       Times Over Voted         NP          NaN      901           0
# 77039               Write-in         NP          NaN      900           4
# 77041  Number of Under Votes         NP          NaN      902           0
# 77042       Times Over Voted         NP          NaN      901           0
#
# [16485 rows x 15 columns]

# %%
# Making sure rows with nulls in 'cand_party' are only under and overvotes, which we can discard
df_nan_cand_party = df[df['cand_party'].isna()]
df_nan_cand_party
# Out:
#        index county_code county_name   elec_date precinct_id  \
# 70359    577         POL        Polk  11/04/2014         102
# 70360    578         POL        Polk  11/04/2014         103
# 70361    579         POL        Polk  11/04/2014         104
# 70362    580         POL        Polk  11/04/2014         105
# 70363    581         POL        Polk  11/04/2014         107
# ...      ...         ...         ...         ...         ...
# 72774   8677         POL        Polk  11/04/2014         410
# 72775   8678         POL        Polk  11/04/2014         412
# 72776   8679         POL        Polk  11/04/2014         419
# 72777   8680         POL        Polk  11/04/2014         422
# 72778   8681         POL        Polk  11/04/2014         423
#
#                                                 poll_loc  total_reg  \
# 70359  GREEN POND BAPTIST CHURCH 5995 GREENPOND CHURC...       1068
# 70360                       POLO PARK 426 POLO PARK BLVD       3182
# 70361             POLO PARK EAST 525 POLO PARK EAST BLVD       2477
# 70362  RIDGE MOBILE HOME PARK CLUBHOUSE 49473 HIGHWAY 27       1098
# 70363  NEW LIFE COMMUNITY CHURCH 530 COMMONWEALTH AVE SW       3870
# ...                                                  ...        ...
# 72774   CALVARY FIRST ASSEMBLY OF GOD 4550 E JOHNSON AVE        898
# 72775        POINCIANA COMMUNITY CENTER 395 MARIGOLD AVE       6517
# 72776  TUSCANY PRESERVE AT LAKE MARION 1850 PACIFIC ROAD       4959
# 72777  SUNLAKE TERRACE ESTATES 6555-16 OLD LAKE WILSO...        208
# 72778           LAKE HAMILTON WOMAN'S CLUB 85 N OMAHA ST         35
#
#               contest_name     district  contest_code cand_or_issue  \
# 70359  U.S. Representative  District 10        140100     OverVotes
# 70360  U.S. Representative  District 10        140100     OverVotes
# 70361  U.S. Representative  District 10        140100     OverVotes
# 70362  U.S. Representative  District 10        140100     OverVotes
# 70363  U.S. Representative  District 10        140100     OverVotes
# ...                    ...          ...           ...           ...
# 72774        State Senator  District 14        240140    UnderVotes
# 72775        State Senator  District 14        240140    UnderVotes
# 72776        State Senator  District 14        240140    UnderVotes
# 72777        State Senator  District 14        240140    UnderVotes
# 72778        State Senator  District 14        240140    UnderVotes
#
#       cand_party  cand_id  doe_num  vote_total
# 70359        NaN      0.0      901           0
# 70360        NaN      0.0      901           0
# 70361        NaN      0.0      901           0
# 70362        NaN      0.0      901           0
# 70363        NaN      0.0      901           0
# ...          ...      ...      ...         ...
# 72774        NaN      0.0      902          38
# 72775        NaN      0.0      902         113
# 72776        NaN      0.0      902          94
# 72777        NaN      0.0      902           2
# 72778        NaN      0.0      902           8
#
# [966 rows x 15 columns]

# %%
# Making sure rows with nulls in 'cand_party' are only under and overvotes, which we can discard
df_nan_cand_party['cand_or_issue'].unique()
# Out:
# array(['OverVotes', 'UnderVotes'], dtype=object)

# %% [markdown]
# Looks like rows containing NaNs in cand_party are either rows describing overvotes and undervotes, or pertain to nonpartisan races that are not relevant to this analysis. Let's double check that latter assumption, and then drop those rows:

# %%
df_nan_cand_party[~df_nan_cand_party['cand_or_issue'].isin(['UnderVotes', 'OverVotes'])]['contest_name'].unique()
# Out:
# array([], dtype=object)

# %% [markdown]
# Assumptions confirmed.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82603 entries, 0 to 82602
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          82603 non-null  int64
#  1   county_code    82603 non-null  object
#  2   county_name    82603 non-null  object
#  3   elec_date      82603 non-null  object
#  4   precinct_id    82603 non-null  object
#  5   poll_loc       73261 non-null  object
#  6   total_reg      82603 non-null  int64
#  7   contest_name   82603 non-null  object
#  8   district       76582 non-null  object
#  9   contest_code   82603 non-null  int64
#  10  cand_or_issue  82603 non-null  object
#  11  cand_party     81637 non-null  object
#  12  cand_id        81876 non-null  float64
#  13  doe_num        82603 non-null  int64
#  14  vote_total     82603 non-null  int64
# dtypes: float64(1), int64(5), object(9)
# memory usage: 9.5+ MB

# %%
df = df.dropna(subset=['cand_party'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81637 entries, 0 to 82602
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          81637 non-null  int64
#  1   county_code    81637 non-null  object
#  2   county_name    81637 non-null  object
#  3   elec_date      81637 non-null  object
#  4   precinct_id    81637 non-null  object
#  5   poll_loc       72295 non-null  object
#  6   total_reg      81637 non-null  int64
#  7   contest_name   81637 non-null  object
#  8   district       75950 non-null  object
#  9   contest_code   81637 non-null  int64
#  10  cand_or_issue  81637 non-null  object
#  11  cand_party     81637 non-null  object
#  12  cand_id        80910 non-null  float64
#  13  doe_num        81637 non-null  int64
#  14  vote_total     81637 non-null  int64
# dtypes: float64(1), int64(5), object(9)
# memory usage: 10.0+ MB

# %% [markdown]
# Looks like we still have nulls in `poll_loc` (which is fine), `district`, and `cand_id` -- let's take a look at those.

# %%
# Create a df with just the rows containing a null value in the district column
df_nan_district = df[df['district'].isna()]
df_nan_district.head(5)
# Out:
#        index county_code county_name  elec_date precinct_id poll_loc  \
# 57918   1477         PAL  Palm Beach  11/4/2014        1002     1002
# 57919   1478         PAL  Palm Beach  11/4/2014        1004     1004
# 57920   1479         PAL  Palm Beach  11/4/2014        1006     1006
# 57921   1480         PAL  Palm Beach  11/4/2014        1008     1008
# 57922   1481         PAL  Palm Beach  11/4/2014        1010     1010
#
#        total_reg                      contest_name district  contest_code  \
# 57918          0  Governor and Lieutenant Governor      NaN        160000
# 57919          2  Governor and Lieutenant Governor      NaN        160000
# 57920          0  Governor and Lieutenant Governor      NaN        160000
# 57921          0  Governor and Lieutenant Governor      NaN        160000
# 57922          0  Governor and Lieutenant Governor      NaN        160000
#
#        cand_or_issue cand_party      cand_id  doe_num  vote_total
# 57918  Adrian Wyllie        LPF  106930498.0    60196           0
# 57919  Adrian Wyllie        LPF  106930498.0    60196           0
# 57920  Adrian Wyllie        LPF  106930498.0    60196           0
# 57921  Adrian Wyllie        LPF  106930498.0    60196           0
# 57922  Adrian Wyllie        LPF  106930498.0    60196           0

# %% [markdown]
# This is a little weird. Looks like we have NaNs in the district column for Governor and Lt. Governor candidates, in rows where vote tallies are indeed present. Is this just for the libertarian party candidate (as we can see in the above head window)? Let's check.

# %%
# Is this only present for the Governor's race? Doesn't look like it.
df_nan_district['contest_name'].unique()
# Out:
# array(['Governor and Lieutenant Governor'], dtype=object)

# %%
# Is this only present in Palm Beach? Doesn't look like it.
df_nan_district['county_name'].unique()
# Out:
# array(['Palm Beach', 'Polk', 'Seminole'], dtype=object)

# %%
# Is this only present for LPF party candidates? Doesn't look like it.
df_nan_district['cand_party'].unique()
# Out:
# array(['LPF', 'DEM', 'NPA', 'REP', 'NP'], dtype=object)

# %% [markdown]
# It looks like the only races that we're interested in that have null values in the `district` column are statewide and don't really have a district anyway. We'll just replace these NaNs with blank cells and move on.

# %%
# We can fill NaNs in this column for rows for statewide races with a blank to be consistent with other dataframes.
df['district'].fillna('', inplace=True)
df.sample(5)
# Out:
#        index county_code county_name   elec_date precinct_id  \
# 42355   2899         LEE         Lee  11/04/2014          33
# 41083   4131         LAK        Lake  11/04/2014          48
# 9156   20460         BRO     Broward  11/04/2014        Q042
# 52160   7896         ORA      Orange  11/04/2014         308
# 77304   1268         STJ   St. Johns  11/04/2014         203
#
#                poll_loc  total_reg                      contest_name  \
# 42355          POLL 033       2494               U.S. Representative
# 41083           48 0048       2729               U.S. Representative
# 9156           Q042 287       1451  Governor and Lieutenant Governor
# 52160   Precinct 308 83       2199  Governor and Lieutenant Governor
# 77304  Heritage Landing       4462  Governor and Lieutenant Governor
#
#            district  contest_code          cand_or_issue cand_party  \
# 42355   District 19        140190             UnderVotes
# 41083   District 10        140100        Michael McKenna        DEM
# 9156                       160000  Scott / Lopez-Cantera        REP
# 52160                      160000             UnderVotes
# 77304                      160000        Burkett / Matos        NPA
#
#            cand_id  doe_num  vote_total
# 42355          0.0      902          46
# 41083  120752577.0    60384         525
# 9156   103093132.0    61253         369
# 52160          0.0      902          10
# 77304  108852312.0    63420           5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81637 entries, 0 to 82602
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          81637 non-null  int64
#  1   county_code    81637 non-null  object
#  2   county_name    81637 non-null  object
#  3   elec_date      81637 non-null  object
#  4   precinct_id    81637 non-null  object
#  5   poll_loc       72295 non-null  object
#  6   total_reg      81637 non-null  int64
#  7   contest_name   81637 non-null  object
#  8   district       81637 non-null  object
#  9   contest_code   81637 non-null  int64
#  10  cand_or_issue  81637 non-null  object
#  11  cand_party     81637 non-null  object
#  12  cand_id        80910 non-null  float64
#  13  doe_num        81637 non-null  int64
#  14  vote_total     81637 non-null  int64
# dtypes: float64(1), int64(5), object(9)
# memory usage: 10.0+ MB

# %% [markdown]
# Okay, we're at a point where the only remaining nulls are in `cand_id` and `poll_loc`, neither of which are really vital. We can move on from filling in NaNs.

# %% [markdown]
# ## Step 5: Standardizing Contest Names
#
# Earlier we saw that different counties recorded the Governor's race (and a few other statewide races, but we're not interested in those) slightly different. Let's fix those.

# %%
races = df['contest_name'].unique()
print(races)
print(len(races))
# Out:
# ['U.S. Representative' 'Governor and Lieutenant Governor'
#  'State Representative' 'State Senator']
# 4

# %%
# def select_races(df):
#     df = df[df.contest_name.isin(['Governor',\
#                                 'United States Senator',\
#                                 'U.S. REPRESENTATIVE',\
#                                 'Representative in Congress',\
#                                 'GOVERNOR AND  LT.GOVERNOR',\
#                                 'STATE SENATOR',\
#                                 'STATE REPRESENTATIVE',\
#                                 'Governor and Lieutenant Governor',\
#                                 'U.S. Representative',\
#                                 'State Senator',\
#                                 'State Representative'])]\
#                                 .reset_index()
#     return df

# %%
# df_narrowed = select_races(df)
# df_narrowed.info()

# %% [markdown]
# ## Step (Final): Check for completeness
# Finally, let's just double check to make sure all counties and races are present in our final output:

# %%
counties = df['county_name'].unique()
print(counties)
print(len(counties))
# All counties are present and accounted for
# Out:
# ['Alachua' 'Baker' 'Bay' 'Bradford' 'Brevard' 'Broward' 'Calhoun'
#  'Charlotte' 'Citrus' 'Clay' 'Collier' 'Columbia' 'Miami-Dade' 'Desoto'
#  'Dixie' 'Duval' 'Escambia' 'Flagler' 'Franklin' 'Gadsden' 'Gilchrist'
#  'Glades' 'Gulf' 'Hamilton' 'Hardee' 'Hendry' 'Hernando' 'Highlands'
#  'Hillsborough' 'Holmes' 'Indian River' 'Jackson' 'Jefferson' 'Lafayette'
#  'Lake' 'Lee' 'Leon' 'Levy' 'Liberty' 'Madison' 'Manatee' 'Monroe'
#  'Marion' 'Martin' 'Nassau' 'Okaloosa' 'Okeechobee' 'Orange' 'Osceola'
#  'Palm Beach' 'Pasco' 'Pinellas' 'Polk' 'Putnam' 'Santa Rosa' 'Sarasota'
#  'Seminole' 'St. Johns' 'St. Lucie' 'Sumter' 'Suwannee' 'Taylor' 'Union'
#  'Volusia' 'Wakulla' 'Walton' 'Washington']
# 67
