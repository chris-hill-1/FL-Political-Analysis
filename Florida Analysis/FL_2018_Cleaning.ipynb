# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import csv
import os
import glob

# %% [markdown]
# ## Step 1: Reformat and Ingest Data

# %%
# Combine county files into single dataframe
def merge_files(directory):
    target_files = glob.glob(directory)
    combined_df = pd.DataFrame()
    for file in target_files:
        df = pd.read_table(file, names=['county_code', 'county_name', 'elec_num', 'elec_date', 'elec_name', 'precinct_id', 'poll_loc', 'total_reg', 'total_reg_r', 'total_reg_d', 'total_reg_other', 'contest_name', 'district', 'contest_code', 'cand_or_issue', 'cand_party', 'cand_id', 'doe_num', 'vote_total'], encoding_errors='replace')
        combined_df = pd.concat([combined_df, df])
    return combined_df

# %%
location = "C:\\Users\\canor\\Documents\\GitHub\\FL-Political-Analysis\\Florida Analysis\\FL 2018 by Precinct\\*"

df = merge_files(location)

# %%
# Examine dataframe for size, dtypes, and NaNs
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 743093 entries, 0 to 1343
# Data columns (total 19 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   county_code      743093 non-null  object
#  1   county_name      743093 non-null  object
#  2   elec_num         743093 non-null  int64
#  3   elec_date        743093 non-null  object
#  4   elec_name        743093 non-null  object
#  5   precinct_id      743093 non-null  object
#  6   poll_loc         733018 non-null  object
#  7   total_reg        743093 non-null  int64
#  8   total_reg_r      743093 non-null  int64
#  9   total_reg_d      743093 non-null  int64
#  10  total_reg_other  743093 non-null  int64
#  11  contest_name     743093 non-null  object
#  12  district         743093 non-null  object
#  13  contest_code     743093 non-null  int64
#  14  cand_or_issue    743093 non-null  object
#  15  cand_party       743093 non-null  object
#  16  cand_id          743093 non-null  int64
#  17  doe_num          743093 non-null  int64
#  18  vote_total       743093 non-null  int64
# dtypes: int64(9), object(10)
# memory usage: 113.4+ MB

# %%
# Examine sample just to get a visual sense of the shape of the data
df.sample(10)
# Out:
#       county_code county_name  elec_num   elec_date              elec_name  \
# 39253         DAD  Miami-Dade     10481  11/06/2018  2018 General Election
# 6192          PAL  Palm Beach     10481  11/06/2018  2018 General Election
# 35259         DAD  Miami-Dade     10481  11/06/2018  2018 General Election
# 1             SAR    Sarasota     10481  11/06/2018  2018 General Election
# 24629         PAL  Palm Beach     10481  11/06/2018  2018 General Election
# 6278          LEO        Leon     10481  11/06/2018  2018 General Election
# 25946         PIN    Pinellas     10481  11/06/2018  2018 General Election
# 30390         BRO     Broward     10481  11/06/2018  2018 General Election
# 78661         DAD  Miami-Dade     10481  11/06/2018  2018 General Election
# 45988         PAL  Palm Beach     10481  11/06/2018  2018 General Election
#
#       precinct_id                                 poll_loc  total_reg  \
# 39253         409                 PCT 409/460/464/487 0257       2547
# 6192         1098                               1098, 1124       1008
# 35259         369                         PCT 301/369 0173          0
# 1             101                                      101        129
# 24629        1370                                     1370        319
# 6278         2509  2509  -- ALARM International Ministries       1844
# 25946         507                                      507       2134
# 30390        N009                                     N009       1224
# 78661         802                             PCT 802 0512       1900
# 45988        3076             3052, 3058, 3060, 3066, 3076        165
#
#        total_reg_r  total_reg_d  total_reg_other  \
# 39253            0            0                0
# 6192             0            0                0
# 35259            0            0                0
# 1                0            0                0
# 24629            0            0                0
# 6278             0            0                0
# 25946            0            0                0
# 30390            0            0                0
# 78661            0            0                0
# 45988            0            0                0
#
#                                             contest_name  \
# 39253                         Representative in Congress
# 6192                               United States Senator
# 35259  Amendment No. 5: Supermajority Vote Required t...
# 1                                  United States Senator
# 24629    Palm Beach Soil and Water Conservation District
# 6278                            Retention of Brad Thomas
# 25946                   Retention of Darryl C. Casanueva
# 30390                         Representative in Congress
# 78661  Amendment No. 7: First Responder and Military ...
# 45988                                      Circuit Judge
#
#                                        district  contest_code  \
# 39253                               District 25        140250
# 6192                                                   120000
# 35259   Authorize, or Raise State Taxes or Fees        900005
# 1                                                      120000
# 24629                                   Group 1        871451
# 6278             First District Court of Appeal        520103
# 25946           Second District Court of Appeal        520202
# 30390                               District 23        140230
# 78661                                                  900007
# 45988           15th Judicial Circuit, Group 13        551513
#
#            cand_or_issue cand_party    cand_id  doe_num  vote_total
# 39253         UnderVotes                     0      902          36
# 6192         Bill Nelson        DEM  113049868    70482         291
# 35259          OverVotes                     0      901           0
# 1            Bill Nelson        DEM  113049868    70482          63
# 24629      David E. Legg        NOP  112337790    72663          60
# 6278          UnderVotes                     0      902         215
# 25946          OverVotes                     0      901           0
# 30390        Don Endriss        NPA  102206295    70870           5
# 78661   No for Rejection        NOP          0       20         477
# 45988  Scott Ryan Kerner        NOP  112074024    70225          31

# %% [markdown]
# ## Step 2: Removing Duplicates

# %%
df.duplicated().sum()
# Out:
# 212

# %% [markdown]
# Looks like we have some dupes! Let's take a look and just make sure we're good to drop them.

# %%
df_dupe = df[df.duplicated(keep=False) == True]

# %%
# See what precincts these rows are from
df_dupe['precinct_id'].unique()
# Out:
# array([463, 658], dtype=object)

# %%
# See if any of the rows contain vote totals
df_dupe_vt = df_dupe[df_dupe['vote_total'] != 0]
df_dupe_vt.head()
# Out:
# Empty DataFrame
# Columns: [county_code, county_name, elec_num, elec_date, elec_name, precinct_id, poll_loc, total_reg, total_reg_r, total_reg_d, total_reg_other, contest_name, district, contest_code, cand_or_issue, cand_party, cand_id, doe_num, vote_total]
# Index: []

# %% [markdown]
# Upon closer investigations, it looks like all of the dupes are from two precincts in Miami-Dade, and none of the rows register any vote totals -- safe to drop!

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## Step 3: Removing Extraneous Columns
# Having already cleaned the 2012, 2014, and 2016 data, I know that there are a handful of columns we can remove off the bat:

# %%
df = df.drop(columns=['total_reg_r', 'total_reg_d', 'total_reg_other', 'elec_num', 'elec_name'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 742881 entries, 0 to 1343
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   county_code    742881 non-null  object
#  1   county_name    742881 non-null  object
#  2   elec_date      742881 non-null  object
#  3   precinct_id    742881 non-null  object
#  4   poll_loc       732806 non-null  object
#  5   total_reg      742881 non-null  int64
#  6   contest_name   742881 non-null  object
#  7   district       742881 non-null  object
#  8   contest_code   742881 non-null  int64
#  9   cand_or_issue  742881 non-null  object
#  10  cand_party     742881 non-null  object
#  11  cand_id        742881 non-null  int64
#  12  doe_num        742881 non-null  int64
#  13  vote_total     742881 non-null  int64
# dtypes: int64(5), object(9)
# memory usage: 85.0+ MB

# %% [markdown]
# ## Step 4: Standardizing Contest Names
#
# Since we're only interested in six races (President, Governor, U.S. Senate, State Senate, U.S. Representative, and State Representative), we need to comb through this list and identify any entries in `contest_name` that suggests it refers to one of those races. We could use regex string matching, but I'll do it manually to make sure there isn't some weird description that some random county used that we wouldn't predict.

# %%
# Look at all listed races and select those that are relevant
df['contest_name'].unique()
# Out:
# array(['United States Senator', 'Representative in Congress', 'Governor',
#        'Attorney General', 'Chief Financial Officer',
#        'Commissioner of Agriculture', 'State Senator',
#        'County Commissioner', 'Retention of Alan Lawson',
#        'Retention of Harvey Jay', 'Retention of Stephanie Ray',
#        'Retention of Brad Thomas', 'Retention of Kemmerly Thomas',
#        'Retention of Allen Winsor', 'Circuit Judge', 'County Court Judge',
#        'School Board', 'Alachua Soil and Water Conservation District',
#        'Amendment No. 1: Increased Homestead Property Tax Exemption',
#        'Amendment No. 2: Limitations on Property Tax Assessments',
#        'Amendment No. 3: Voter Control of Gambling in Florida',
#        'Amendment No. 4: Voting Restoration Amendment',
#        'Amendment No. 5: Supermajority Vote Required to Impose, Authorize, or Raise State Taxes or Fees',
#        'Amendment No. 6: Rights of Crime Victims; Judges',
#        'Amendment No. 7: First Responder and Military Member Survivor Benefits; Public Colleges and Universities',
#        'Amendment No. 9: Prohibits Offshore Oil and Gas Drilling; Prohibits Vaping in Enclosed Indoor Workplaces',
#        'Amendment No. 10: State and Local Government Structure and Operation',
#        'Amendment No. 11: Property Rights; Removal of Obsolete Provision; Criminal Statutes',
#        'Amendment No. 12: Lobbying and Abuse of Office by Public Officers',
#        'Amendment No. 13: Ends Dog Racing', 'State Representative',
#        'Lake Powell Residential Golf Community Development District',
#        'Canaveral Port Authority', 'Retention of Eric Eisnaugle',
#        'Brevard Soil and Water Conservation District',
#        'Sebastian Inlet Tax District',
#        'Barefoot Bay Recreation District (Vote for 3)',
#        'Viera East Community Development District',
#        'Heritage Isle at Viera Community Development District',
#        'Retention of Burton C. Conner', 'Retention of Jeffrey T. Kuntz',
#        'Retention of Carole Y. Taylor',
#        'Broward Soil and Water Conservation District',
#        'Griffin Lakes Community Development District',
#        'Walnut Creek Community Development District', 'State Attorney',
#        'Charlotte County Airport Authority',
#        'Retention of Anthony K. Black',
#        'Retention of Darryl C. Casanueva',
#        'Retention of Edward C. LaRose',
#        'Retention of Susan H. Rothstein-Youakim',
#        'Riverwood Community Development District',
#        'Heritage Oak Park Community Development District',
#        'Citrus County Community Charitable Foundation',
#        'Citrus County Mosquito Control District',
#        'Homosassa Special Water District',
#        'Clay Soil and Water Conservation District',
#        'Crossing at Fleming Island Community Development District',
#        'Fleming Island Plantation Community Development District',
#        'Collier Mosquito Control District',
#        'Greater Naples Fire Rescue District',
#        'Port of the Islands Community Improvement District',
#        'Lely Community Development District',
#        "Fiddler's Creek Community Development District",
#        'North Collier Fire Control and Rescue District',
#        'Cedar Hammock Community Development District',
#        'Santa Fe Soil and Water Conservation District',
#        'Retention of Kevin Emas', 'Retention of Ivan F. Fernandez',
#        'Retention of Norma Shepard Lindsey',
#        'Retention of Robert Joshua Luck',
#        'South Dade Soil and Water Conservation District',
#        'Majorca Isles Community Development District',
#        'Coconut Cay Community Development District',
#        'Islands at Doral III Community Development District',
#        'Vizcaya in Kendall  Community Development District',
#        'Lakes by the Bay South Community Development District',
#        'East Homestead Community Development District',
#        'Baywinds Community Development District',
#        'South Dade Venture Community Development District',
#        'Tax Collector', 'Duval Soil and Water Conservation District',
#        'Principal One Community Development District',
#        'Tolomato Community Development District',
#        'Bartram Springs Community Development District',
#        'Emerald Coast Utilities Authority',
#        'Escambia Soil and Water Conservation District',
#        'Dunes Community Development District',
#        'Gadsden Soil and Water Conservation District',
#        'Property Appraiser',
#        'Lehigh Acres Municipal Services Improvement District',
#        'Clerk of the Circuit Court and Comptroller',
#        'Spring Ridge Community Development District',
#        'Spring Lake Improvement District', 'Sheriff',
#        'Hillsborough Soil and Water Conservation District',
#        'Cory Lakes Community Development District',
#        'Tampa Palms Open Space & Transportation Community Development District',
#        'The Hammocks Community Development District',
#        'Park Place Community Development District',
#        'River Bend Community Development District',
#        'The Highlands Community Development District',
#        'Mira Lago West Community Development District',
#        'Harbor Bay Community Development District',
#        'Belmont Community Development District',
#        'South Fork East Community Development District',
#        'Rivercrest Community Development District',
#        'Holmes Creek Soil and Water Conservation District',
#        'Indian River Soil and Water Conservation District',
#        'Indian River Mosquito Control District',
#        'Lake County Water Authority',
#        'North Lake County Hospital District',
#        'Arlington Ridge Community Development District',
#        'Lee Memorial Health System Board of Directors',
#        'Lee County Mosquito Control District',
#        'Lehigh Acres Fire Control and Rescue District',
#        'San Carlos Park Fire Protection and Rescue Service District',
#        'Bonita Springs Fire Control and Rescue District',
#        'Matlacha/Pine Island Fire Control District',
#        'Sanibel Fire & Rescue District',
#        'Iona-McGregor Fire Protection and Rescue Service District',
#        'Fort Myers Beach Fire Control District',
#        'North Fort Myers Fire Control and Rescue Service District',
#        'Gateway Services Community Development District',
#        'Stoneybrook Community Development District',
#        'Moody River Estates Community Development District',
#        'Habitat Community Development District',
#        'Leon Soil and Water Conservation District',
#        'Piney Z Community Development District',
#        'Capital Region Community Development District',
#        'Madison Soil and Water Conservation District',
#        'Parrish Fire Control District',
#        'Harrison Ranch Community Development District',
#        'East Manatee Fire Rescue District',
#        'Heritage Harbour North Community Development District',
#        'Greyhawk Landing Community Development District',
#        'Waters Edge Community Development District',
#        'Cedar Hammock Fire Control District',
#        'Harbourage at Braden River Community Development District',
#        'Tara Community Development District',
#        'University Place Community Development District',
#        'Florida Keys Mosquito Control District',
#        'Key Largo Fire Rescue and Emergency Medical Services District',
#        'North Okaloosa Fire District', 'Destin Fire Control District',
#        'Orange Soil and Water Conservation District',
#        'Osceola Soil and Water Conservation District',
#        'Indian Point Common Facilities District',
#        'Celebration Community Development District',
#        'Remington Community Development District',
#        'Brighton Lakes Community Development District',
#        'Harmony Community Development District',
#        'Palm Beach Soil and Water Conservation District',
#        'Northern Palm Beach County Improvement District',
#        'Indian Trail Improvement District', 'Port of Palm Beach District',
#        'Thousand Oaks Community Development District',
#        'Sonoma Bay Community Development District',
#        'Pasco County Mosquito Control District',
#        'Lake Padgett Estates Independent Special District (Vote for 5)',
#        'Country Walk Community Development District',
#        'Preserve at Wilderness Lake Community Development District',
#        'Longleaf Community Development District',
#        'Northwood Community Development District',
#        'Oakstead Community Development District',
#        'Oak Creek Community Development District',
#        'Lakeside Community Development District',
#        'Connerton West Community Development District',
#        'Lealman Special Fire Control District',
#        'Palm Harbor Special Fire Control and Rescue District',
#        'East Lake Tarpon Special Fire Control District',
#        'Polk Soil and Water Conservation District',
#        'Golden Lakes Community Development District',
#        'Poinciana Community Development District',
#        'Poinciana West Community Development District',
#        'Lake Ashton Community Development District',
#        'Lake Ashton II Community Development District',
#        'Holley-Navarre Fire District',
#        'Sarasota County Charter Review Board',
#        'Sarasota County Public Hospital Board',
#        'Seminole Soil and Water Conservation District',
#        'Anastasia Mosquito Control District',
#        'St. Augustine-St. Johns County Airport Authority',
#        'Julington Creek Plantation Community Development District',
#        'Durbin Crossing Community Development District',
#        'Rivers Edge Community Development District',
#        'Heritage Landing Community Development District',
#        'St. Augustine Port',
#        'Turnbull Creek Community Development District',
#        'Sweetwater Creek Community Development District',
#        'Lake Lucie Community Development District',
#        'Portofino Shores Community Development District',
#        'St. Lucie West Services District',
#        'Tradition Community Development District No. 4',
#        'Tradition Community Development District No. 6',
#        'Village Community Development District No. 5',
#        'Village Community Development District No. 6',
#        'North Sumter County Utility Dependent District',
#        'Village Community Development District No. 9',
#        'Village Community Development District No. 10',
#        'Village Community Development District No. 12',
#        'Suwannee County Conservation District', 'County Council',
#        'Volusia Soil and Water Conservation District',
#        'West Volusia Hospital Authority'], dtype=object)

# %% [markdown]
# Above, we can see that 1) there are a lot of races represented in the data and 2) they look like they're finally standardized across the state! This makes things much easier, but for the sake of sticking to a standardized process, I'll go through the above set of contest names. I have extracted the ones that correspond to races we're interested in. Using dictionaries, we can standardize the naming convention for our races.

# %%
df['contest_name'] = df['contest_name']\
.replace(dict.fromkeys(['PRESIDENT OF THE UNITED STATES'], 'President of the United States'))\
.replace(dict.fromkeys(['United States Senator', 'UNITED STATES SENATOR'], 'U.S. Senator'))\
.replace(dict.fromkeys(['Congress 10', 'Congress 9', 'Congress 15', 'Congress 17', 'Representative in Congress', 'U.S. REPRESENTATIVE', 'REPRESENTATIVE IN CONGRESS'], 'U.S. Representative'))\
.replace(dict.fromkeys(['GOVERNOR AND  LT.GOVERNOR', 'Governor'], 'Governor and Lieutenant Governor'))\
.replace(dict.fromkeys(['STATE SENATOR', 'Senate 14'], 'State Senator'))\
.replace(dict.fromkeys(['STATE REPRESENTATIVE', 'House 39', 'House 40', 'House 41', 'House 42'], 'State Representative'))

# %% [markdown]
# ## Step 5: Narrowing to Races
# And now we can more confidently narrow to our six contest types:

# %%
df = df[df.contest_name.isin(['President of the United States',\
                              'U.S. Senator',\
                              'U.S. Representative',\
                              'Governor and Lieutenant Governor',\
                              'State Senator',\
                              'State Representative'])]\
                            .reset_index()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137322 entries, 0 to 137321
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   index          137322 non-null  int64
#  1   county_code    137322 non-null  object
#  2   county_name    137322 non-null  object
#  3   elec_date      137322 non-null  object
#  4   precinct_id    137322 non-null  object
#  5   poll_loc       135287 non-null  object
#  6   total_reg      137322 non-null  int64
#  7   contest_name   137322 non-null  object
#  8   district       137322 non-null  object
#  9   contest_code   137322 non-null  int64
#  10  cand_or_issue  137322 non-null  object
#  11  cand_party     137322 non-null  object
#  12  cand_id        137322 non-null  int64
#  13  doe_num        137322 non-null  int64
#  14  vote_total     137322 non-null  int64
# dtypes: int64(6), object(9)
# memory usage: 15.7+ MB

# %% [markdown]
# ## Step 6: Dealing With NaN Cells

# %%
# Looking for any rows with nulls
df_nan = df[df.isna().any(axis=1)]

df_nan
# Out:
#        index county_code county_name   elec_date precinct_id poll_loc  \
# 26206   4956         DAD  Miami-Dade  11/06/2018         100      NaN
# 26207   4957         DAD  Miami-Dade  11/06/2018         100      NaN
# 26208   4958         DAD  Miami-Dade  11/06/2018         100      NaN
# 26209   4959         DAD  Miami-Dade  11/06/2018         100      NaN
# 26210   4960         DAD  Miami-Dade  11/06/2018         100      NaN
# ...      ...         ...         ...         ...         ...      ...
# 49870  26239         DUV       Duval  11/06/2018        1415      NaN
# 49871  26258         DUV       Duval  11/06/2018        1415      NaN
# 49872  26259         DUV       Duval  11/06/2018        1415      NaN
# 49873  26260         DUV       Duval  11/06/2018        1415      NaN
# 49874  26261         DUV       Duval  11/06/2018        1415      NaN
#
#        total_reg                      contest_name      district  \
# 26206       3951                      U.S. Senator
# 26207       3951                      U.S. Senator
# 26208       3951                      U.S. Senator
# 26209       3951                      U.S. Senator
# 26210       3951                      U.S. Senator
# ...          ...                               ...           ...
# 49870       2261  Governor and Lieutenant Governor
# 49871       2261              State Representative   District 15
# 49872       2261              State Representative   District 15
# 49873       2261              State Representative   District 15
# 49874       2261              State Representative   District 15
#
#        contest_code      cand_or_issue cand_party    cand_id  doe_num  \
# 26206        120000         Rick Scott        REP  103093132    71039
# 26207        120000        Bill Nelson        DEM  113049868    70482
# 26208        120000       WriteinVotes                     0      900
# 26209        120000          OverVotes                     0      901
# 26210        120000         UnderVotes                     0      902
# ...             ...                ...        ...        ...      ...
# 49870        160000         UnderVotes                     0      902
# 49871        260150       Wyman Duggan        REP  103393517    69999
# 49872        260150  Tracye Ann Polson        DEM  118326666    70061
# 49873        260150          OverVotes                     0      901
# 49874        260150         UnderVotes                     0      902
#
#        vote_total
# 26206         199
# 26207         820
# 26208           2
# 26209           0
# 26210           4
# ...           ...
# 49870          10
# 49871         605
# 49872         970
# 49873           0
# 49874          50
#
# [2035 rows x 15 columns]

# %% [markdown]
# It looks like the only nulls in this dataset are in the `poll_loc` column. That's great -- we can just leave those in for the time being.

# %% [markdown]
# ## Step 7: Check for Completeness
# Finally, let's just double check to make sure all counties and races are present in our final output:

# %%
counties = df['county_name'].unique()
print(counties)
print(len(counties))
# All counties are present and accounted for
# Out:
# ['Alachua' 'Baker' 'Bay' 'Bradford' 'Brevard' 'Broward' 'Calhoun'
#  'Charlotte' 'Citrus' 'Clay' 'Collier' 'Columbia' 'Miami-Dade' 'Desoto'
#  'Dixie' 'Duval' 'Escambia' 'Flagler' 'Franklin' 'Gadsden' 'Gilchrist'
#  'Glades' 'Gulf' 'Hamilton' 'Hardee' 'Hendry' 'Hernando' 'Highlands'
#  'Hillsborough' 'Holmes' 'Indian River' 'Jackson' 'Jefferson' 'Lafayette'
#  'Lake' 'Lee' 'Leon' 'Levy' 'Liberty' 'Madison' 'Manatee' 'Monroe'
#  'Marion' 'Martin' 'Nassau' 'Okaloosa' 'Okeechobee' 'Orange' 'Osceola'
#  'Palm Beach' 'Pasco' 'Pinellas' 'Polk' 'Putnam' 'Santa Rosa' 'Sarasota'
#  'Seminole' 'St. Johns' 'St. Lucie' 'Sumter' 'Suwannee' 'Taylor' 'Union'
#  'Volusia' 'Wakulla' 'Walton' 'Washington']
# 67

# %% [markdown]
# All 67 counties are represented in the dataset, so this looks complete.

# %%
races = df['contest_name'].unique()
print(races)
print(len(races))
# Out:
# ['U.S. Senator' 'U.S. Representative' 'Governor and Lieutenant Governor'
#  'State Senator' 'State Representative']
# 5

# %% [markdown]
# 2018 had no presidential contest, so this looks complete.

# %% [markdown]
# ## Step 8: Save to CSV

# %%
# df.to_csv('fl_2018_cleaned.csv')
