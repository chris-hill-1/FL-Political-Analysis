# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import csv
import os
import glob

# %% [markdown]
# ## Step 1: Reformat and Ingest Data

# %%
# Combine county files into single dataframe
def merge_files(directory):
    target_files = glob.glob(directory)
    combined_df = pd.DataFrame()
    for file in target_files:
        df = pd.read_table(file, names=['county_code', 'county_name', 'elec_num', 'elec_date', 'elec_name', 'precinct_id', 'poll_loc', 'total_reg', 'total_reg_r', 'total_reg_d', 'total_reg_other', 'contest_name', 'district', 'contest_code', 'cand_or_issue', 'cand_party', 'cand_id', 'doe_num', 'vote_total'], encoding_errors='replace')
        combined_df = pd.concat([combined_df, df])
    return combined_df

# %%
location = "C:\\Users\\canor\\Documents\\GitHub\\FL-Political-Analysis\\Florida Analysis\\FL 2020 by Precinct\\*"

df = merge_files(location)

# %%
# Examine dataframe for size, dtypes, and NaNs
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 553307 entries, 0 to 839
# Data columns (total 19 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   county_code      553307 non-null  object
#  1   county_name      553307 non-null  object
#  2   elec_num         553307 non-null  int64
#  3   elec_date        553307 non-null  object
#  4   elec_name        553307 non-null  object
#  5   precinct_id      553307 non-null  object
#  6   poll_loc         452021 non-null  object
#  7   total_reg        553307 non-null  int64
#  8   total_reg_r      553307 non-null  int64
#  9   total_reg_d      553307 non-null  int64
#  10  total_reg_other  553307 non-null  int64
#  11  contest_name     553307 non-null  object
#  12  district         553307 non-null  object
#  13  contest_code     553307 non-null  int64
#  14  cand_or_issue    553307 non-null  object
#  15  cand_party       553307 non-null  object
#  16  cand_id          553307 non-null  int64
#  17  doe_num          553307 non-null  int64
#  18  vote_total       553307 non-null  int64
# dtypes: int64(9), object(10)
# memory usage: 84.4+ MB

# %%
# Examine sample just to get a visual sense of the shape of the data
df.sample(10)
# Out:
#       county_code   county_name  elec_num   elec_date              elec_name  \
# 250           GAD       Gadsden     10866  11/03/2020  2020 General Election
# 1576          OKA      Okaloosa     10866  11/03/2020  2020 General Election
# 1783          LEO          Leon     10866  11/03/2020  2020 General Election
# 10339         HIL  Hillsborough     10866  11/03/2020  2020 General Election
# 2923          PAL    Palm Beach     10866  11/03/2020  2020 General Election
# 37766         PAL    Palm Beach     10866  11/03/2020  2020 General Election
# 5956          BRO       Broward     10866  11/03/2020  2020 General Election
# 114           HAM      Hamilton     10866  11/03/2020  2020 General Election
# 31            BAK         Baker     10866  11/03/2020  2020 General Election
# 31219         BRO       Broward     10866  11/03/2020  2020 General Election
#
#       precinct_id                                      poll_loc  total_reg  \
# 250             1                Pre 1 Centenary United Methodi       1458
# 1576           10                                            10       6885
# 1783         4101  4101-4401 -- Premier Health & Fitness Center       1602
# 10339         920                                           920        270
# 2923         2202                                           NaN          8
# 37766        2094                                           NaN        688
# 5956         J008                                          J008        509
# 114             3                     3 - White Springs Library        954
# 31             4B                           Taylor Voting House        646
# 31219        C023                                          C023       5954
#
#        total_reg_r  total_reg_d  total_reg_other  \
# 250              0            0                0
# 1576             0            0                0
# 1783             0            0                0
# 10339            0            0                0
# 2923             0            0                0
# 37766            0            0                0
# 5956             0            0                0
# 114              0            0                0
# 31               0            0                0
# 31219            0            0                0
#
#                          contest_name                          district  \
# 250        Representative in Congress                        District 5
# 1576     Retention of Joseph Lewis Jr    First District Court of Appeal
# 1783       Representative in Congress                        District 2
# 10339                         Sheriff
# 2923   President of the United States
# 37766      Retention of Alan O. Forst   Fourth District Court of Appeal
# 5956       Representative in Congress                       District 20
# 114                     State Senator                        District 3
# 31     President of the United States
# 31219                   Circuit Judge   17th Judicial Circuit, Group 16
#
#        contest_code              cand_or_issue cand_party    cand_id  doe_num  \
# 250          140050                 Gary Adler        REP  103559929    75184
# 1576         520101                         No        NOP  104990520       20
# 1783         140020                 UnderVotes                     0      902
# 10339        335000               Ron McMullen        NPA  110518450    76113
# 2923         100000  De La Fuente / Richardson        REF          0    74772
# 37766        520401                  OverVotes                     0      901
# 5956         140200          Alcee L. Hastings        DEM  101602313    75013
# 114          240030       Marva Harris Preston        REP  101469260    74381
# 31           100000  De La Fuente / Richardson        REF          0    74772
# 31219        551716             George Odom Jr        NOP  103254918    74590
#
#        vote_total
# 250           415
# 1576         1322
# 1783          347
# 10339          24
# 2923            0
# 37766           0
# 5956          266
# 114           390
# 31              0
# 31219        1675

# %% [markdown]
# ## Step 2: Removing Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No dupes! Great!

# %% [markdown]
# ## Step 3: Removing Extraneous Columns
# Having already cleaned the 2012 and 2014 data, I know that there are a handful of columns we can remove off the bat:

# %%
df = df.drop(columns=['total_reg_r', 'total_reg_d', 'total_reg_other', 'elec_num', 'elec_name'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 553307 entries, 0 to 839
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   county_code    553307 non-null  object
#  1   county_name    553307 non-null  object
#  2   elec_date      553307 non-null  object
#  3   precinct_id    553307 non-null  object
#  4   poll_loc       452021 non-null  object
#  5   total_reg      553307 non-null  int64
#  6   contest_name   553307 non-null  object
#  7   district       553307 non-null  object
#  8   contest_code   553307 non-null  int64
#  9   cand_or_issue  553307 non-null  object
#  10  cand_party     553307 non-null  object
#  11  cand_id        553307 non-null  int64
#  12  doe_num        553307 non-null  int64
#  13  vote_total     553307 non-null  int64
# dtypes: int64(5), object(9)
# memory usage: 63.3+ MB

# %% [markdown]
# ## Step 4: Standardizing Contest Names
#
# Since we're only interested in six races (President, Governor, U.S. Senate, State Senate, U.S. Representative, and State Representative), we need to comb through this list and identify any entries in `contest_name` that suggests it refers to one of those races. We could use regex string matching, but I'll do it manually to make sure there isn't some weird description that some random county used that we wouldn't predict.

# %%
# Look at all listed races and select those that are relevant
df['contest_name'].unique()
# Out:
# array(['President of the United States', 'Representative in Congress',
#        'State Representative', 'County Commissioner',
#        'Retention of Carlos G. Muñiz', 'Retention of Joseph Lewis Jr',
#        'Retention of Scott Makar', 'Retention of Rachel Nordby',
#        'Retention of Tim Osterhaus', 'Retention of Clay Roberts',
#        'Retention of Adam S. Tanenbaum',
#        'Amendment No. 1: Citizenship Requirement to Vote in Florida Elections',
#        'Amendment No. 2: Raising Florida’s Minimum Wage',
#        'Amendment No. 3: All Voters Vote in Primary Elections for State Legislature, Governor, and Cabinet',
#        'Amendment No. 4: Voter Approval of Constitutional Amendments',
#        'Amendment No. 5: Limitations on Homestead Property Tax Assessments; increased portability period to transfer accrued benefit',
#        'Amendment No. 6: Ad Valorem Tax Discount for Spouses of Certain Deceased Veterans Who Had Permanent, Combat-Related Disabilities',
#        'State Senator', 'Clerk of the Circuit Court and Comptroller',
#        'Beach Mosquito Control District',
#        'Lake Powell Residential Golf Community Development District',
#        'Superintendent of Schools', 'Supervisor of Elections', 'Sheriff',
#        'Canaveral Port Authority', 'Retention of Kerry I. Evander',
#        'Retention of John M. Harris', 'Retention of Richard B. Orfinger',
#        'Retention of Meredith Sasso', 'Retention of F. Rand Wallis',
#        'Barefoot Bay Recreation District (Vote for 3)',
#        'Baytree Community Development District',
#        'Brevard Soil and Water Conservation District',
#        'Viera East Community Development District', 'State Attorney',
#        'Public Defender', 'Retention of Alan O. Forst',
#        'Retention of Mark W. Klingensmith',
#        'Retention of Martha C. Warner', 'Circuit Judge', 'School Board',
#        'Broward Soil and Water Conservation District',
#        'Cypress Cove Community Development District',
#        'Griffin Lakes Community Development District',
#        'Walnut Creek Community Development District',
#        'Charlotte County Airport Authority', 'Retention of Drew Atkinson',
#        'Retention of Morris Silberman', 'Retention of Daniel H. Sleet',
#        'Retention of Andrea Teves Smith',
#        'Charlotte Soil and Water Conservation District',
#        'Heritage Oak Park Community Development District',
#        'Property Appraiser', 'Citrus County Mosquito Control District',
#        'Crossing at Fleming Island Community Development District',
#        'Rolling Hills Community Development District',
#        'South Village Community Development District',
#        'Collier Mosquito Control District',
#        'Greater Naples Fire Rescue District',
#        'Pelican Marsh Community Development District',
#        'Port of the Islands Community Improvement District',
#        'Tax Collector', 'Clerk of the Circuit Court',
#        'Retention of Monica Gordo', 'Retention of Eric William Hendon',
#        'Retention of Fleur Jeannine Lobree', 'Retention of Thomas Logue',
#        'Retention of Bronwyn Catherine Miller', 'Mayor',
#        'Hemingway Point Community Development District',
#        'Lakes by the Bay South Community Development District',
#        'Majorca Isles Community Development District',
#        'South Dade Venture Community Development District',
#        'Stonegate Community Development District', 'City Council',
#        'Tolomato Community Development District',
#        'Bartram Springs Community Development District',
#        'Duval Soil and Water Conservation District',
#        'Emerald Coast Utilities Authority',
#        'Escambia Soil and Water Conservation District',
#        'Dunes Community Development District',
#        'East Flagler Mosquito Control District',
#        'Grand Haven Community Development District',
#        'Gadsden Soil and Water Conservation District',
#        'Lehigh Acres Municipal Services Improvement District',
#        'Central County Water Control District',
#        'Sun N Lake of Sebring Improvement District (Vote for 2)',
#        'County Court Judge',
#        'Arbor Greene Community Development District',
#        'Cheval West Community Development District',
#        'Cory Lakes Community Development District',
#        'Cypress Creek Community Development District',
#        'DG Farms Community Development District',
#        'Encore Community Development District',
#        'Fishhawk Ranch Community Development District',
#        'Harbor Bay Community Development District',
#        'Heritage Harbor Community Development District',
#        'Heritage Isles Community Development District',
#        'Hillsborough Soil and Water Conservation District',
#        'K-Bar Ranch Community Development District',
#        'Park Creek Community Development District',
#        'Park Place Community Development District',
#        'River Bend Community Development District',
#        'Rivercrest Community Development District',
#        'Spring Lake Community Development District',
#        'Triple Creek Community Development District',
#        'Waterset North Community Development District',
#        'Indian River County Hospital District',
#        'Indian River Mosquito Control District',
#        'Indian River Soil and Water Conservation District',
#        'Lake County Water Authority',
#        'North Lake County Hospital District',
#        'Bayside Improvement Community Development District',
#        'Bella Vida Community Development District',
#        'Brooks of Bonita Springs Community Development District',
#        'Fort Myers Beach Fire Control District',
#        'Gateway Services Community Development District',
#        'Habitat Community Development District',
#        'Iona-McGregor Fire Protection and Rescue Service District',
#        'Laguna Lakes Community Development District',
#        'Lee County Mosquito Control District',
#        'Lee Memorial Health System Board of Directors',
#        'Lehigh Acres Fire Control and Rescue District',
#        'Matlacha/Pine Island Fire Control District',
#        'Parklands Lee Community Development District',
#        'Paseo Community Development District',
#        'Upper Captiva Fire Protection and Rescue Service District',
#        'Leon Soil and Water Conservation District',
#        'Capital Region Community Development District',
#        'Piney Z Community Development District',
#        'Levy Soil and Water Conservation District',
#        'Cedar Hammock Fire Control District',
#        'Forest Creek Community Development District',
#        'Lakewood Ranch Community Development District 5',
#        'Lakewood Ranch Community Development District 6',
#        'Manatee County Mosquito Control District',
#        'Palms of Terra Ceia Bay Community Development District',
#        'Tara Community Development District',
#        'Waters Edge Community Development District',
#        'West Manatee Fire and Rescue District',
#        'Key Largo Fire Rescue and Emergency Medical Services District',
#        'Amelia Concourse Community Development District',
#        'Nassau Soil and Water Conservation District',
#        'North Okaloosa Fire District', 'Greeneway Improvement District',
#        'Orange Soil and Water Conservation District',
#        'Stoneybrook West Community Development District',
#        'Vista Lakes Community Development District',
#        'Anthem Park Community Development District',
#        'Brighton Lakes Community Development District',
#        'Celebration Community Development District',
#        'Concorde Estates Community Development District',
#        'Harmony Community Development District',
#        'Osceola Soil and Water Conservation District',
#        'Remington Community Development District',
#        'Port of Palm Beach District', 'Indian Trail Improvement District',
#        'Palm Beach Soil and Water Conservation District',
#        'Asturia Community Development District',
#        'Concord Station Community Development District',
#        'Dupree Lakes Community Development District',
#        'Heritage Pines Community Development District',
#        'Lake Bernadette Community Development District',
#        'Lakeshore Ranch Community Development District',
#        'Meadow Pointe Community Development District',
#        'Meadow Pointe II Community Development District',
#        'Northwood Community Development District',
#        'Oak Creek Community Development District',
#        'Oakstead Community Development District',
#        'Pasco County Mosquito Control District',
#        'Preserve at Wilderness Lake Community Development District',
#        'East Lake Tarpon Special Fire Control District',
#        'Clearwater Cay Community Development District',
#        'Lake Ashton Community Development District',
#        'Lake Ashton II Community Development District',
#        'Lake Region Lakes Management District',
#        'Pace Fire Rescue District',
#        'Sarasota County Charter Review Board',
#        'Sarasota County Public Hospital Board',
#        'Lakeside Plantation Community Development District',
#        'Sarasota Soil and Water Conservation District',
#        'Venetian Community  Development District',
#        'Seminole Soil and Water Conservation District',
#        'Anastasia Mosquito Control District',
#        'Brandy Creek Community Development District',
#        'Heritage Landing Community Development District',
#        'Marshall Creek Community Development District',
#        'Rivers Edge Community Development District',
#        'St. Augustine-St. Johns County Airport Authority',
#        'St. Augustine Port',
#        'St. Johns Soil and Water Conservation District',
#        'Six Mile Creek Community Development District',
#        'Sweetwater Creek Community Development District',
#        'Turnbull Creek Community Development District',
#        'Portofino Shores Community Development District',
#        'River Place on the St. Lucie Community Development District',
#        'Saint Lucie Soil and Water Conservation District',
#        'Tradition Community Development District No. 6',
#        'North Sumter County Utility Dependent District',
#        'Village Community Development District No. 5',
#        'Village Community Development District No. 9',
#        'County Council Chair', 'County Council',
#        'Volusia Soil and Water Conservation District',
#        'West Volusia Hospital Authority',
#        'South Walton County Mosquito Control District'], dtype=object)

# %% [markdown]
# Above, we can see that there are a lot of races represented in the data. While not fully standardized prior to 2018, it looks like they are standardized in subsequent elections. Just to confirm, I reviewed the above list manually looking for non-standard descriptions that might refer to one of our races and we'll run the following standardization step anyway.

# %%
df['contest_name'] = df['contest_name']\
.replace(dict.fromkeys(['PRESIDENT OF THE UNITED STATES'], 'President of the United States'))\
.replace(dict.fromkeys(['United States Senator', 'UNITED STATES SENATOR'], 'U.S. Senator'))\
.replace(dict.fromkeys(['Congress 10', 'Congress 9', 'Congress 15', 'Congress 17', 'Representative in Congress', 'U.S. REPRESENTATIVE', 'REPRESENTATIVE IN CONGRESS'], 'U.S. Representative'))\
.replace(dict.fromkeys(['GOVERNOR AND  LT.GOVERNOR', 'Governor'], 'Governor and Lieutenant Governor'))\
.replace(dict.fromkeys(['STATE SENATOR', 'Senate 14'], 'State Senator'))\
.replace(dict.fromkeys(['STATE REPRESENTATIVE', 'House 39', 'House 40', 'House 41', 'House 42'], 'State Representative'))

# %% [markdown]
# ## Step 5: Narrowing to Races
# And now we can more confidently narrow to our six contest types:

# %%
df = df[df.contest_name.isin(['President of the United States',\
                              'U.S. Senator',\
                              'U.S. Representative',\
                              'Governor and Lieutenant Governor',\
                              'State Senator',\
                              'State Representative'])]\
                            .reset_index()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122811 entries, 0 to 122810
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   index          122811 non-null  int64
#  1   county_code    122811 non-null  object
#  2   county_name    122811 non-null  object
#  3   elec_date      122811 non-null  object
#  4   precinct_id    122811 non-null  object
#  5   poll_loc       100493 non-null  object
#  6   total_reg      122811 non-null  int64
#  7   contest_name   122811 non-null  object
#  8   district       122811 non-null  object
#  9   contest_code   122811 non-null  int64
#  10  cand_or_issue  122811 non-null  object
#  11  cand_party     122811 non-null  object
#  12  cand_id        122811 non-null  int64
#  13  doe_num        122811 non-null  int64
#  14  vote_total     122811 non-null  int64
# dtypes: int64(6), object(9)
# memory usage: 14.1+ MB

# %% [markdown]
# ## Step 6: Dealing With NaN Cells

# %%
# Looking for any rows with nulls
df_nan = df[df.isna().any(axis=1)]

df_nan
# Out:
#        index county_code county_name   elec_date precinct_id poll_loc  \
# 37703    125         DUV       Duval  11/03/2020        1001      NaN
# 37704    126         DUV       Duval  11/03/2020        1002      NaN
# 37705    127         DUV       Duval  11/03/2020        1003      NaN
# 37706    128         DUV       Duval  11/03/2020        1004      NaN
# 37707    129         DUV       Duval  11/03/2020        1005      NaN
# ...      ...         ...         ...         ...         ...      ...
# 97832  18781         PAL  Palm Beach  11/03/2020        5124      NaN
# 97833  18782         PAL  Palm Beach  11/03/2020        5126      NaN
# 97834  18783         PAL  Palm Beach  11/03/2020        5158      NaN
# 97835  18784         PAL  Palm Beach  11/03/2020        5160      NaN
# 97836  18785         PAL  Palm Beach  11/03/2020        5172      NaN
#
#        total_reg                    contest_name      district  contest_code  \
# 37703       3307  President of the United States                      100000
# 37704       3457  President of the United States                      100000
# 37705       2114  President of the United States                      100000
# 37706       2617  President of the United States                      100000
# 37707       3961  President of the United States                      100000
# ...          ...                             ...           ...           ...
# 97832        394            State Representative   District 91        260910
# 97833        491            State Representative   District 91        260910
# 97834       1779            State Representative   District 91        260910
# 97835       1741            State Representative   District 91        260910
# 97836        776            State Representative   District 91        260910
#
#        cand_or_issue cand_party  cand_id  doe_num  vote_total
# 37703  Trump / Pence        REP        0    74773         172
# 37704  Trump / Pence        REP        0    74773          91
# 37705  Trump / Pence        REP        0    74773          51
# 37706  Trump / Pence        REP        0    74773          64
# 37707  Trump / Pence        REP        0    74773         140
# ...              ...        ...      ...      ...         ...
# 97832     UnderVotes                   0      902          19
# 97833     UnderVotes                   0      902          24
# 97834     UnderVotes                   0      902          70
# 97835     UnderVotes                   0      902          78
# 97836     UnderVotes                   0      902          32
#
# [22318 rows x 15 columns]

# %% [markdown]
# It looks like the only nulls in this dataset are in the `poll_loc` column. That's great -- we can just leave those in for the time being.

# %% [markdown]
# ## Step 7: Check for Completeness
# Finally, let's just double check to make sure all counties and races are present in our final output:

# %%
counties = df['county_name'].unique()
print(counties)
print(len(counties))
# All counties are present and accounted for
# Out:
# ['Alachua' 'Baker' 'Bay' 'Bradford' 'Brevard' 'Broward' 'Calhoun'
#  'Charlotte' 'Citrus' 'Clay' 'Collier' 'Columbia' 'Miami-Dade' 'Desoto'
#  'Dixie' 'Duval' 'Escambia' 'Flagler' 'Franklin' 'Gadsden' 'Gilchrist'
#  'Glades' 'Gulf' 'Hamilton' 'Hardee' 'Hendry' 'Hernando' 'Highlands'
#  'Hillsborough' 'Holmes' 'Indian River' 'Jackson' 'Jefferson' 'Lafayette'
#  'Lake' 'Lee' 'Leon' 'Levy' 'Liberty' 'Madison' 'Manatee' 'Monroe'
#  'Marion' 'Martin' 'Nassau' 'Okaloosa' 'Okeechobee' 'Orange' 'Osceola'
#  'Palm Beach' 'Pasco' 'Pinellas' 'Polk' 'Putnam' 'Santa Rosa' 'Sarasota'
#  'Seminole' 'St. Johns' 'St. Lucie' 'Sumter' 'Suwannee' 'Taylor' 'Union'
#  'Volusia' 'Wakulla' 'Walton' 'Washington']
# 67

# %% [markdown]
# All 67 counties are represented in the dataset, so this looks complete.

# %%
races = df['contest_name'].unique()
print(races)
print(len(races))
# Out:
# ['President of the United States' 'U.S. Representative'
#  'State Representative' 'State Senator']
# 4

# %% [markdown]
# 2020 had no gubernatorial or U.S. Senate contests, so this looks complete.

# %% [markdown]
# ## Step 8: Save to CSV

# %%
# df.to_csv('fl_2020_cleaned.csv')

# %%
df[df['county_code'] == 'WAS']
# Out:
#         index county_code county_name   elec_date precinct_id  \
# 122643      0         WAS  Washington  11/03/2020           1
# 122644      1         WAS  Washington  11/03/2020           2
# 122645      2         WAS  Washington  11/03/2020           3
# 122646      3         WAS  Washington  11/03/2020           4
# 122647      4         WAS  Washington  11/03/2020           5
# ...       ...         ...         ...         ...         ...
# 122806    163         WAS  Washington  11/03/2020           8
# 122807    164         WAS  Washington  11/03/2020           9
# 122808    165         WAS  Washington  11/03/2020          11
# 122809    166         WAS  Washington  11/03/2020          12
# 122810    167         WAS  Washington  11/03/2020          15
#
#                               poll_loc  total_reg  \
# 122643             CARYVILLE TOWN HALL        475
# 122644     FIVE POINT COMMUNITY CENTER       1053
# 122645  HINSON CROSSROADS FIRE STATION        641
# 122646  AGRICULTURE CENTER - CHIPLEY         4018
# 122647                VERNON CITY HALL       1629
# ...                                ...        ...
# 122806                ARMORY - CHIPLEY       1733
# 122807                WAUSAU TOWN HALL       1134
# 122808                  EBRO CITY HALL        439
# 122809                       GREENHEAD       2393
# 122810  SUNNY HILLS COMMUNITY CENTER         1357
#
#                           contest_name     district  contest_code  \
# 122643  President of the United States                     100000
# 122644  President of the United States                     100000
# 122645  President of the United States                     100000
# 122646  President of the United States                     100000
# 122647  President of the United States                     100000
# ...                                ...          ...           ...
# 122806             U.S. Representative   District 2        140020
# 122807             U.S. Representative   District 2        140020
# 122808             U.S. Representative   District 2        140020
# 122809             U.S. Representative   District 2        140020
# 122810             U.S. Representative   District 2        140020
#
#         cand_or_issue cand_party  cand_id  doe_num  vote_total
# 122643  Trump / Pence        REP        0    74773         185
# 122644  Trump / Pence        REP        0    74773         735
# 122645  Trump / Pence        REP        0    74773         425
# 122646  Trump / Pence        REP        0    74773        2264
# 122647  Trump / Pence        REP        0    74773         956
# ...               ...        ...      ...      ...         ...
# 122806     UnderVotes                   0      902         183
# 122807     UnderVotes                   0      902          58
# 122808     UnderVotes                   0      902          57
# 122809     UnderVotes                   0      902         123
# 122810     UnderVotes                   0      902         104
#
# [168 rows x 15 columns]
