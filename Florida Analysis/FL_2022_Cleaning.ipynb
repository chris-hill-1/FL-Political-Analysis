# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import csv
import os
import glob

# %% [markdown]
# ## Step 1: Reformat and Ingest Data

# %%
# Combine county files into single dataframe
def merge_files(directory):
    target_files = glob.glob(directory)
    combined_df = pd.DataFrame()
    for file in target_files:
        df = pd.read_table(file, names=['county_code', 'county_name', 'elec_num', 'elec_date', 'elec_name', 'precinct_id', 'poll_loc', 'total_reg', 'total_reg_r', 'total_reg_d', 'total_reg_other', 'contest_name', 'district', 'contest_code', 'cand_or_issue', 'cand_party', 'cand_id', 'doe_num', 'vote_total'], encoding_errors='replace')
        combined_df = pd.concat([combined_df, df])
    return combined_df

# %%
location = "C:\\Users\\canor\\Documents\\GitHub\\FL-Political-Analysis\\Florida Analysis\\FL 2022 by Precinct\\*"

df = merge_files(location)

# %%
# Examine dataframe for size, dtypes, and NaNs
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 609323 entries, 0 to 1031
# Data columns (total 19 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   county_code      609323 non-null  object
#  1   county_name      609323 non-null  object
#  2   elec_num         609323 non-null  int64
#  3   elec_date        609323 non-null  object
#  4   elec_name        609323 non-null  object
#  5   precinct_id      608549 non-null  object
#  6   poll_loc         569737 non-null  object
#  7   total_reg        609323 non-null  int64
#  8   total_reg_r      609323 non-null  int64
#  9   total_reg_d      609323 non-null  int64
#  10  total_reg_other  609323 non-null  int64
#  11  contest_name     609323 non-null  object
#  12  district         609323 non-null  object
#  13  contest_code     609323 non-null  int64
#  14  cand_or_issue    609323 non-null  object
#  15  cand_party       609323 non-null  object
#  16  cand_id          609323 non-null  int64
#  17  doe_num          609323 non-null  int64
#  18  vote_total       609323 non-null  int64
# dtypes: int64(9), object(10)
# memory usage: 93.0+ MB

# %%
# Examine sample just to get a visual sense of the shape of the data
df.sample(10)
# Out:
#       county_code county_name  elec_num   elec_date              elec_name  \
# 30926         PAL  Palm Beach     26906  11/08/2022  2022 General Election
# 10914         PAS       Pasco     26906  11/08/2022  2022 General Election
# 2535          BRE     Brevard     26906  11/08/2022  2022 General Election
# 25940         DAD  Miami-Dade     26906  11/08/2022  2022 General Election
# 749           ORA      Orange     26906  11/08/2022  2022 General Election
# 4635          MRN      Marion     26906  11/08/2022  2022 General Election
# 54014         PAL  Palm Beach     26906  11/08/2022  2022 General Election
# 7276          VOL     Volusia     26906  11/08/2022  2022 General Election
# 5188          SAR    Sarasota     26906  11/08/2022  2022 General Election
# 1904          DUV       Duval     26906  11/08/2022  2022 General Election
#
#       precinct_id        poll_loc  total_reg  total_reg_r  total_reg_d  \
# 30926        4502            4502       1984            0            0
# 10914         103             103       2298            0            0
# 2535          500    Precinct 500       1775            0            0
# 25940        4590  PRECINCT 459.0        908            0            0
# 749           632         PCT 632       2734            0            0
# 4635         4060            4060       3371            0            0
# 54014        3718            3718       2374            0            0
# 7276          906             906       1763            0            0
# 5188          515             515       1831            0            0
# 1904          811             811       2211            0            0
#
#        total_reg_other                      contest_name  \
# 30926                0       Port of Palm Beach District
# 10914                0    Retention of Craig C. Villanti
# 2535                 0  Governor and Lieutenant Governor
# 25940                0           Chief Financial Officer
# 749                  0             United States Senator
# 4635                 0    Retention of Charles T. Canady
# 54014                0       Retention of Cory J. Ciklin
# 7276                 0        Retention of Jorge Labarga
# 5188                 0    Retention of Charles T. Canady
# 1904                 0        Representative in Congress
#
#                               district  contest_code     cand_or_issue  \
# 30926                          Group 4        421340     Doreen Benson
# 10914  Second District Court of Appeal        520208               Yes
# 2535                                          160000  Roos / Rorabaugh
# 25940                                         160500         OverVotes
# 749                                           120000    Dennis Misigoy
# 4635      Justice of the Supreme Court        500001               Yes
# 54014  Fourth District Court of Appeal        520402         OverVotes
# 7276      Justice of the Supreme Court        500004         OverVotes
# 5188      Justice of the Supreme Court        500001               Yes
# 1904                        District 4        140040        UnderVotes
#
#       cand_party    cand_id  doe_num  vote_total
# 30926        REP  111927282    81541         346
# 10914        NOP  113787369       10         753
# 2535         LPF  109876282    82220           2
# 25940                     0      901           0
# 749          LPF  109912678    79517           6
# 4635         NOP  113445454       10         751
# 54014                     0      901           1
# 7276                      0      901           1
# 5188         NOP  113445454       10         535
# 1904                      0      902          20

# %% [markdown]
# ## Step 2: Removing Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No dupes! Great!

# %% [markdown]
# ## Step 3: Removing Extraneous Columns
# Having already cleaned all of the other data, I know that there are a handful of columns we can remove off the bat:

# %%
df = df.drop(columns=['total_reg_r', 'total_reg_d', 'total_reg_other', 'elec_num', 'elec_name'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 609323 entries, 0 to 1031
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   county_code    609323 non-null  object
#  1   county_name    609323 non-null  object
#  2   elec_date      609323 non-null  object
#  3   precinct_id    608549 non-null  object
#  4   poll_loc       569737 non-null  object
#  5   total_reg      609323 non-null  int64
#  6   contest_name   609323 non-null  object
#  7   district       609323 non-null  object
#  8   contest_code   609323 non-null  int64
#  9   cand_or_issue  609323 non-null  object
#  10  cand_party     609323 non-null  object
#  11  cand_id        609323 non-null  int64
#  12  doe_num        609323 non-null  int64
#  13  vote_total     609323 non-null  int64
# dtypes: int64(5), object(9)
# memory usage: 69.7+ MB

# %% [markdown]
# ## Step 4: Standardizing Contest Names
#
# Since we're only interested in six races (President, Governor, U.S. Senate, State Senate, U.S. Representative, and State Representative), we need to comb through this list and identify any entries in `contest_name` that suggests it refers to one of those races. We could use regex string matching, but I'll do it manually to make sure there isn't some weird description that some random county used that we wouldn't predict.

# %%
# Look at all listed races and select those that are relevant
df['contest_name'].unique()
# Out:
# array(['United States Senator', 'Representative in Congress',
#        'Governor and Lieutenant Governor', 'Attorney General',
#        'Chief Financial Officer', 'Commissioner of Agriculture',
#        'State Senator', 'State Representative', 'County Commissioner',
#        'Retention of Charles T. Canady', 'Retention of John D. Couriel',
#        'Retention of Jamie Grosshans', 'Retention of Jorge Labarga',
#        'Retention of Ricky Polston', 'Retention of Ross L. Bilbrey',
#        'Retention of Susan Kelsey', 'Retention of Bobby Long',
#        'Retention of Lori S. Rowe', 'Retention of Bo Winokur',
#        'Circuit Judge', 'Alachua Soil and Water Conservation District',
#        'Amendment No. 1: Limitation on Assessment of Real Property Used for Residential Purposes',
#        'Amendment No. 2: Abolishing the Constitution Revision Commission',
#        'Amendment No. 3: Additional Homestead Property Tax Exemption for Specified Critical Public Services Workforce',
#        'School Board', 'Retention of Jay Cohen',
#        'Retention of James A. Edwards', 'Retention of Brian D. Lambert',
#        'Retention of Mary Nardella', 'Retention of Dan Traver',
#        'Retention of Carrie Ann Wozniak', 'County Court Judge',
#        'Barefoot Bay Recreation District (Vote for 3)',
#        'Baytree Community Development District',
#        'Montecito Community Development District',
#        'Retention of Ed Artau', 'Retention of Cory J. Ciklin',
#        'Retention of Dorian K. Damoorgian',
#        'Retention of Jonathan D. Gerber', 'Retention of Robert M. Gross',
#        'Retention of Spencer D. Levine', 'Retention of Melanie G. May',
#        'Central Broward Water Control District',
#        'Coral Bay Community Development District',
#        'Plantation Acres Improvement District (Vote for 3)',
#        'Turtle Run Community Development District',
#        'Walnut Creek Community Development District',
#        'Retention of Patricia Joan Kelly',
#        'Retention of Nelly N. Khouzam', 'Retention of Suzanne Y. Labrit',
#        'Retention of Matt Lucas', 'Retention of Robert Morris',
#        'Retention of Stevan Travis Northcutt',
#        'Retention of John K. Stargel', 'Retention of Craig C. Villanti',
#        'Englewood Water District',
#        'Heritage Oak Park Community Development District',
#        'Riverwood Community Development District',
#        'Citrus County Mosquito Control District',
#        'Homosassa Special Water District',
#        'Fleming Island Plantation Community Development District',
#        'Lake Asbury Municipal Service Benefit District',
#        'Rolling Hills Community Development District',
#        'South Village Community Development District',
#        'Cedar Hammock Community Development District',
#        'Collier Mosquito Control District',
#        'Greater Naples Fire Rescue District',
#        'Hacienda Lakes Community Development District',
#        'North Collier Fire Control and Rescue District',
#        'Port of the Islands Community Improvement District',
#        'Winding Cypress Community Development District',
#        'Retention of Alexander Spicola Bokor',
#        'Retention of Edwin A. Scales',
#        'Cutler Cay Community Development District',
#        'Fountainbleau Lakes Community Development District',
#        'Bartram Springs Community Development District',
#        'Duval Soil and Water Conservation District',
#        'Villages of Westport Community Development District',
#        'Emerald Coast Utilities Authority', 'Santa Rosa Island Authority',
#        'Deer Run Community Development District',
#        'Gadsden Soil and Water Conservation District',
#        'Port LaBelle Community Development District',
#        'Lehigh Acres Municipal Services Improvement District',
#        'Southern Hills Plantation 1 Community Development District',
#        'Sun N Lake of Sebring Improvement District (Vote for 2)',
#        'Arbor Greene Community Development District',
#        'Cory Lakes Community Development District',
#        'Covington Park Community Development District',
#        'Harbor Bay Community Development District',
#        'Heritage Harbor Community Development District',
#        'Hillsborough Soil and Water Conservation District',
#        'K-Bar Ranch Community Development District',
#        'Rivercrest Community Development District',
#        'South Fork East Community Development District',
#        'Tampa Palms Open Space & Transportation Community Development District',
#        'The Hammocks Community Development District',
#        'Waterleaf Community Development District',
#        'Westchase Community Development District',
#        'Indian River County Hospital District',
#        'Indian River Mosquito Control District',
#        'Indian River Soil and Water Conservation District',
#        'Supervisor of Elections',
#        'Arlington Ridge Community Development District',
#        'Lake Soil and Water Conservation District',
#        'Bonita Springs Fire Control and Rescue District',
#        'Cypress Shadows Community Development District',
#        'Lee Memorial Health System Board of Directors',
#        'Lehigh Acres Fire Control and Rescue District',
#        'Lucaya Community Development District',
#        'Matlacha/Pine Island Fire Control District',
#        'Moody River Estates Community Development District',
#        'Paseo Community Development District',
#        'River Hall Community Development District',
#        'Sanibel Public Library District',
#        'South Trail Fire Protection and Rescue Service District',
#        'Tice Fire Protection and Rescue Service District',
#        'Upper Captiva Fire Protection and Rescue Service District',
#        'Piney Z Community Development District',
#        'Copperstone Community Development District',
#        'East Manatee Fire Rescue District',
#        'Heritage Harbour North Community Development District',
#        'Lakewood Ranch Community Development District 2',
#        'Lakewood Ranch Community Development District 4',
#        'Tara Community Development District',
#        'University Place Community Development District',
#        'Waters Edge Community Development District',
#        'West Manatee Fire and Rescue District',
#        'Key Largo Wastewater Treatment District (Vote for 3)',
#        'Loxahatchee River Environmental Control District',
#        'Amelia National Community Development District',
#        'Orange Soil and Water Conservation District',
#        'Randal Park Community Development District',
#        'Anthem Park Community Development District',
#        'Celebration Community Development District',
#        'Concorde Estates Community Development District',
#        'Gramercy Farms Community Development District',
#        'Overoaks Community Development District',
#        'Reunion West Community Development District',
#        'VillaSol Community Development District',
#        'Port of Palm Beach District', 'Indian Trail Improvement District',
#        'Palm Beach Soil and Water Conservation District',
#        'State Attorney', 'Connerton West Community Development District',
#        'Dupree Lakes Community Development District',
#        'The Groves Community Development District',
#        'Lake Padgett Estates Independent Special District (Vote for 5)',
#        'Lakeshore Ranch Community Development District',
#        'Lakeside Community Development District',
#        'Long Lake Ranch Community Development District',
#        'Longleaf Community Development District',
#        'Meadow Pointe II Community Development District',
#        'Mirada Community Development District',
#        'Northwood Community Development District',
#        'Oak Creek Community Development District',
#        'Seven Oaks Community Development District',
#        'Silverado Community Development District',
#        'Suncoast  Community Development District',
#        'Talavera Community Development District',
#        'TSR Community Development District',
#        'Bridgewater Community Development District',
#        'Golden Lakes Community Development District',
#        'Highland Meadows II Community Development District',
#        'Lake Ashton II Community Development District',
#        'Sarasota County Charter Review Board',
#        'Sarasota County Public Hospital Board',
#        'Lakeside Plantation Community Development District',
#        'Venetian Community  Development District',
#        'West Villages Improvement District',
#        'Seminole Soil and Water Conservation District',
#        'Anastasia Mosquito Control District',
#        'Heritage Landing Community Development District',
#        'St. Johns County Airport Authority', 'St. Augustine Port',
#        'Southaven Community Development District',
#        'Sweetwater Creek Community Development District',
#        'Trout Creek Community Development District',
#        'Turnbull Creek Community Development District',
#        'Portofino Shores Community Development District',
#        'River Place on the St. Lucie Community Development District',
#        'St. Lucie West Services District',
#        'Tradition Community Development District No. 5',
#        'North Sumter County Utility Dependent District',
#        'Village Community Development District No. 6', 'County Council'],
#       dtype=object)

# %% [markdown]
# Above, we can see that there are a lot of races represented in the data. While not fully standardized prior to 2018, it looks like they are standardized in subsequent elections. Just to confirm, I reviewed the above list manually looking for non-standard descriptions that might refer to one of our races and we'll run the following standardization step anyway.

# %%
df['contest_name'] = df['contest_name']\
.replace(dict.fromkeys(['PRESIDENT OF THE UNITED STATES'], 'President of the United States'))\
.replace(dict.fromkeys(['United States Senator', 'UNITED STATES SENATOR'], 'U.S. Senator'))\
.replace(dict.fromkeys(['Congress 10', 'Congress 9', 'Congress 15', 'Congress 17', 'Representative in Congress', 'U.S. REPRESENTATIVE', 'REPRESENTATIVE IN CONGRESS'], 'U.S. Representative'))\
.replace(dict.fromkeys(['GOVERNOR AND  LT.GOVERNOR', 'Governor'], 'Governor and Lieutenant Governor'))\
.replace(dict.fromkeys(['STATE SENATOR', 'Senate 14'], 'State Senator'))\
.replace(dict.fromkeys(['STATE REPRESENTATIVE', 'House 39', 'House 40', 'House 41', 'House 42'], 'State Representative'))

# %% [markdown]
# ## Step 5: Narrowing to Races
# And now we can more confidently narrow to our six contest types:

# %%
df = df[df.contest_name.isin(['President of the United States',\
                              'U.S. Senator',\
                              'U.S. Representative',\
                              'Governor and Lieutenant Governor',\
                              'State Senator',\
                              'State Representative'])]\
                            .reset_index()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142119 entries, 0 to 142118
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   index          142119 non-null  int64
#  1   county_code    142119 non-null  object
#  2   county_name    142119 non-null  object
#  3   elec_date      142119 non-null  object
#  4   precinct_id    141921 non-null  object
#  5   poll_loc       134587 non-null  object
#  6   total_reg      142119 non-null  int64
#  7   contest_name   142119 non-null  object
#  8   district       142119 non-null  object
#  9   contest_code   142119 non-null  int64
#  10  cand_or_issue  142119 non-null  object
#  11  cand_party     142119 non-null  object
#  12  cand_id        142119 non-null  int64
#  13  doe_num        142119 non-null  int64
#  14  vote_total     142119 non-null  int64
# dtypes: int64(6), object(9)
# memory usage: 16.3+ MB

# %% [markdown]
# ## Step 6: Dealing With NaN Cells

# %%
# Looking for any rows with nulls
df_nan = df[df.isna().any(axis=1)]

df_nan
# Out:
#         index county_code county_name   elec_date precinct_id  \
# 5937        0         BRO     Broward  11/08/2022           1
# 5938        1         BRO     Broward  11/08/2022           2
# 5939        2         BRO     Broward  11/08/2022           3
# 5940        3         BRO     Broward  11/08/2022           4
# 5941        4         BRO     Broward  11/08/2022           5
# ...       ...         ...         ...         ...         ...
# 142111    400         WAS  Washington  11/08/2022         NaN
# 142112    401         WAS  Washington  11/08/2022         NaN
# 142113    402         WAS  Washington  11/08/2022         NaN
# 142114    403         WAS  Washington  11/08/2022         NaN
# 142115    404         WAS  Washington  11/08/2022         NaN
#
#                          poll_loc  total_reg   contest_name     district  \
# 5937                          NaN       1715   U.S. Senator
# 5938                          NaN       4361   U.S. Senator
# 5939                          NaN       4477   U.S. Senator
# 5940                          NaN       3260   U.S. Senator
# 5941                          NaN       3563   U.S. Senator
# ...                           ...        ...            ...          ...
# 142111           Vernon City Hall          0  State Senator   District 2
# 142112  New Hope - Campbells Park        610  State Senator   District 2
# 142113   Orange Hill Fire Station       1572  State Senator   District 2
# 142114           Armory - Chipley       1545  State Senator   District 2
# 142115                     Wausau       1072  State Senator   District 2
#
#         contest_code cand_or_issue cand_party  cand_id  doe_num  vote_total
# 5937          120000   Marco Rubio        REP        0    81751         590
# 5938          120000   Marco Rubio        REP        0    81751        1710
# 5939          120000   Marco Rubio        REP        0    81751        1093
# 5940          120000   Marco Rubio        REP        0    81751         414
# 5941          120000   Marco Rubio        REP        0    81751         171
# ...              ...           ...        ...      ...      ...         ...
# 142111        240020    UnderVotes                   0      902           5
# 142112        240020    UnderVotes                   0      902           5
# 142113        240020    UnderVotes                   0      902           9
# 142114        240020    UnderVotes                   0      902          14
# 142115        240020    UnderVotes                   0      902           7
#
# [7730 rows x 15 columns]

# %% [markdown]
# Looks like we have nulls in `poll_loc` and `precinct_id` -- the former is fine since we won't be doing anything with that column immediately, but the latter is unusual so let's take a closer look.

# %%
df_nan_precinct_id = df[df['precinct_id'].isna()]

df_nan_precinct_id
# Out:
#         index county_code county_name   elec_date precinct_id  \
# 141855      0         WAS  Washington  11/08/2022         NaN
# 141856      1         WAS  Washington  11/08/2022         NaN
# 141857      2         WAS  Washington  11/08/2022         NaN
# 141858      3         WAS  Washington  11/08/2022         NaN
# 141859      4         WAS  Washington  11/08/2022         NaN
# ...       ...         ...         ...         ...         ...
# 142111    400         WAS  Washington  11/08/2022         NaN
# 142112    401         WAS  Washington  11/08/2022         NaN
# 142113    402         WAS  Washington  11/08/2022         NaN
# 142114    403         WAS  Washington  11/08/2022         NaN
# 142115    404         WAS  Washington  11/08/2022         NaN
#
#                               poll_loc  total_reg   contest_name     district  \
# 141855                       Caryville        421   U.S. Senator
# 141856                     Five Points       1023   U.S. Senator
# 141857               Hinson Crossroads        600   U.S. Senator
# 141858  First Baptist Church - Chipley       3669   U.S. Senator
# 141859                Vernon City Hall          0   U.S. Senator
# ...                                ...        ...            ...          ...
# 142111                Vernon City Hall          0  State Senator   District 2
# 142112       New Hope - Campbells Park        610  State Senator   District 2
# 142113        Orange Hill Fire Station       1572  State Senator   District 2
# 142114                Armory - Chipley       1545  State Senator   District 2
# 142115                          Wausau       1072  State Senator   District 2
#
#         contest_code cand_or_issue cand_party  cand_id  doe_num  vote_total
# 141855        120000   Marco Rubio        REP        0    81751         121
# 141856        120000   Marco Rubio        REP        0    81751         562
# 141857        120000   Marco Rubio        REP        0    81751         329
# 141858        120000   Marco Rubio        REP        0    81751        1742
# 141859        120000   Marco Rubio        REP        0    81751         738
# ...              ...           ...        ...      ...      ...         ...
# 142111        240020    UnderVotes                   0      902           5
# 142112        240020    UnderVotes                   0      902           5
# 142113        240020    UnderVotes                   0      902           9
# 142114        240020    UnderVotes                   0      902          14
# 142115        240020    UnderVotes                   0      902           7
#
# [198 rows x 15 columns]

# %% [markdown]
# Looks like all of the nulls here are in Washington county, and they definitely contain vote totals. Let's confirm.

# %%
df_nan_precinct_id[df_nan_precinct_id['county_code'] != 'WAS']
# Out:
# Empty DataFrame
# Columns: [index, county_code, county_name, elec_date, precinct_id, poll_loc, total_reg, contest_name, district, contest_code, cand_or_issue, cand_party, cand_id, doe_num, vote_total]
# Index: []

# %% [markdown]
# Confirmed. It's surprising that the precinct info isn't included in the dataset -- we may be able to cross reference the 2020 data using polling locations (which tend not to change much year-to-year, especially in smaller counties like Washington) to get the precinct IDs.

# %%
df_nan_precinct_id['poll_loc'].unique()
# Out:
# array(['Caryville', 'Five Points', 'Hinson Crossroads',
#        'First Baptist Church - Chipley', 'Vernon City Hall',
#        'New Hope - Campbells Park', 'Orange Hill Fire Station',
#        'Armory - Chipley', 'Wausau'], dtype=object)

# %%
wash_precincts = {1: "Caryville", 
                  2: 'Five Points', 
                  3: 'Hinson Crossroads', 
                  4: 'First Baptist Church', 
                  5: 'Vernon City Hall',
                  6: 'Campbells Park',
                  7: 'Orange Hill Fire Station',
                  8: 'Armory',
                  9: 'Wausau'}


# df_nan_precinct_id['precinct_id'] = df_nan_precinct_id.apply(
#     lambda row: wash_precincts.items()[0] if 
# )

wash_precincts.keys().type
# Out:
# dict_keys([1, 2, 3, 4, 5, 6, 7, 8, 9])

# %% [markdown]
# ## Step 7: Check for Completeness
# Finally, let's just double check to make sure all counties and races are present in our final output:

# %%
counties = df['county_name'].unique()
print(counties)
print(len(counties))
# All counties are present and accounted for
# Out:
# ['Alachua' 'Baker' 'Bay' 'Bradford' 'Brevard' 'Broward' 'Calhoun'
#  'Charlotte' 'Citrus' 'Clay' 'Collier' 'Columbia' 'Miami-Dade' 'Desoto'
#  'Dixie' 'Duval' 'Escambia' 'Flagler' 'Franklin' 'Gadsden' 'Gilchrist'
#  'Glades' 'Gulf' 'Hamilton' 'Hardee' 'Hendry' 'Hernando' 'Highlands'
#  'Hillsborough' 'Holmes' 'Indian River' 'Jackson' 'Jefferson' 'Lafayette'
#  'Lake' 'Lee' 'Leon' 'Levy' 'Liberty' 'Madison' 'Manatee' 'Monroe'
#  'Marion' 'Martin' 'Nassau' 'Okaloosa' 'Okeechobee' 'Orange' 'Osceola'
#  'Palm Beach' 'Pasco' 'Pinellas' 'Polk' 'Putnam' 'Santa Rosa' 'Sarasota'
#  'Seminole' 'St. Johns' 'St. Lucie' 'Sumter' 'Suwannee' 'Taylor' 'Union'
#  'Volusia' 'Wakulla' 'Walton' 'Washington']
# 67

# %% [markdown]
# All 67 counties are represented in the dataset, so this looks complete.

# %%
races = df['contest_name'].unique()
print(races)
print(len(races))
# Out:
# ['U.S. Senator' 'U.S. Representative' 'Governor and Lieutenant Governor'
#  'State Senator' 'State Representative']
# 5

# %% [markdown]
# 2018 had no presidential contest, so this looks complete.

# %% [markdown]
# ## Step 8: Save to CSV

# %%
# df.to_csv('fl_2018_cleaned.csv')
